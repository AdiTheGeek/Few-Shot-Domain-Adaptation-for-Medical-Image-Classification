# %% [markdown]
# ## 1. Environment Setup

# %%
# Check GPU availability
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Nov 25 12:42:47 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   34C    P0             53W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 179.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# Clone repository (or upload files)
# !git clone https://github.com/AdiTheGeek/Few-Shot-Domain-Adaptation-for-Medical-Image-Classification.git
# %cd Few-Shot-Domain-Adaptation-for-Medical-Image-Classification
# Out:
# fatal: destination path 'Few-Shot-Domain-Adaptation-for-Medical-Image-Classification' already exists and is not an empty directory.
# /content/Few-Shot-Domain-Adaptation-for-Medical-Image-Classification

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.24.0+cu126)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.0.22)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.57.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (3.10.0)
# Collecting pytorch-lightning (from -r requirements.txt (line 10))
#   Downloading pytorch_lightning-2.5.6-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.23.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (4.12.0.88)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.16.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 3)) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 9)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 9)) (3.2.5)
# Collecting torchmetrics>0.7.0 (from pytorch-lightning->-r requirements.txt (line 10))
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning->-r requirements.txt (line 10))
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 11)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 11)) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 11)) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 11)) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 11)) (2.11.10)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 11)) (2.45.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 11)) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 11)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 11)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 4)) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->-r requirements.txt (line 10)) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 11)) (5.0.2)
# Downloading pytorch_lightning-2.5.6-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.6/831.6 kB 49.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 72.3 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.15.2 pytorch-lightning-2.5.6 torchmetrics-1.8.2

# %%
# Import libraries
import os
import sys
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Subset

# Add project to path (if needed)
# sys.path.append('/content/Few-Shot-Domain-Adaptation-for-Medical-Image-Classification')

from configs.config import Config
from data.datasets import SimpleMedicalDataset, get_transforms, sample_few_shot_indices
from models.vit_backbone import ViTWrapper
from models.cnn_backbones import build_cnn
from lora.lora import apply_lora_to_model
from adapters.adapter import attach_adapter_to_vit
from prompts.prompt_tuning import attach_visual_prompt_to_vit
from train.trainer import LitModel
from eval.evaluator import compute_metrics, bootstrap_confidence_interval
from utils.utils import set_seed, count_parameters

import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# GPU count: 1
# GPU name: NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 2. Dataset Preparation
#
# **Note:** You need to prepare your CheXpert and NIH ChestX-ray14 datasets.
#
# Expected structure:
# ```
# data/
# ├── chexpert_train.csv
# ├── chexpert_val.csv
# ├── nih_train.csv
# ├── nih_val.csv
# ├── images/
# │   ├── patient001/
# │   │   ├── study1/
# │   │   │   └── view1.jpg
# ```
#
# CSV format:
# - Column `Path`: relative image path
# - Columns for each of 14 pathologies (0/1 labels, -1 for uncertainty)

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download ashery/chexpert
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ashery/chexpert
# License(s): CC0-1.0
# Downloading chexpert.zip to /content/Few-Shot-Domain-Adaptation-for-Medical-Image-Classification
#  99% 10.6G/10.7G [00:25<00:00, 87.3MB/s]
# 100% 10.7G/10.7G [00:25<00:00, 455MB/s]

# %%
# !unzip chexpert.zip -d ./data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/train/patient60445/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60445/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60446/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60446/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60446/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60447/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60447/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60448/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60448/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60448/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60449/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60449/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60450/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60450/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60451/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60451/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60452/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60452/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60452/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60453/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60453/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60454/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60455/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60455/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60456/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60456/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60457/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60457/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60458/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60458/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60458/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60459/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60459/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60460/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60460/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60460/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60461/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60461/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60462/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60462/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60463/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60464/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60464/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60465/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60465/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60466/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60466/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60467/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60467/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60468/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60468/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60469/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60470/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60471/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60471/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60472/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60472/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60473/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60473/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60474/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60474/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60475/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60475/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60476/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60477/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60477/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60477/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60478/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60478/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60479/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60479/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60480/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60480/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60480/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60480/study2/view2_frontal.jpg
#   inflating: ./data/train/patient60480/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60481/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60481/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60482/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60482/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60483/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60483/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60484/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60484/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60485/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60485/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60486/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60487/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60487/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60488/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60488/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60489/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60489/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60489/study2/view2_frontal.jpg
#   inflating: ./data/train/patient60490/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60490/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60490/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60491/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60491/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60491/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60491/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60492/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60492/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60493/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60493/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60494/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60494/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60494/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60495/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60495/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60495/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60495/study2/view3_lateral.jpg
#   inflating: ./data/train/patient60496/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60496/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60497/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60498/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60498/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60499/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60499/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60500/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60500/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60501/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60501/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60502/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60502/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60502/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60503/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60503/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60504/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60505/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60505/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60506/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60506/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60507/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60507/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60508/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60508/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60509/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60509/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60509/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60510/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60510/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60511/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60511/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60512/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60512/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60512/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60513/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60514/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60514/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60515/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60515/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60516/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60516/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60517/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60517/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60518/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60518/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60519/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60519/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60520/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60520/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60521/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60521/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60521/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60522/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60522/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60523/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60523/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60524/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60524/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60524/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60525/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60525/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60526/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60526/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60526/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60526/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60527/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60527/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60528/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60528/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60529/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60529/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60530/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60530/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60531/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60532/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60532/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60533/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60533/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60534/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60534/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60534/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60534/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60534/study4/view1_frontal.jpg
#   inflating: ./data/train/patient60535/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60535/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60536/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60536/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60537/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60537/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60538/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60539/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60539/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60540/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60540/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60540/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60540/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60541/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60542/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60542/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60543/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60543/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60544/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60544/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60545/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60546/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60546/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60547/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60547/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60548/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60548/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60548/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60549/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60549/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60549/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60550/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60551/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60551/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60551/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60552/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60552/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60553/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60553/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60553/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60554/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60555/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60556/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60557/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60558/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60558/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60559/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60559/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60560/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60560/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60561/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60561/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60562/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60562/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60563/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60563/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60564/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60564/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60565/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60565/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60566/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60566/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60567/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60567/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60567/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60568/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60569/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60570/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60570/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60571/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60571/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60571/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60572/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60572/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60573/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60574/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60575/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60575/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60576/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60577/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60577/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60578/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60578/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60579/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60579/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60579/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60580/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60580/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60581/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60581/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60582/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60583/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60583/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60584/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60584/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60585/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60585/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60585/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60586/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60586/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60587/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60587/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60588/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60588/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60589/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60589/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60590/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60590/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60591/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60591/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60592/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60592/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60593/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60593/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60594/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60595/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60595/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60596/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60596/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60596/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60597/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60597/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60598/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60598/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60599/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60599/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60600/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60600/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60601/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60601/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60602/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60603/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60603/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60603/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60604/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60604/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60605/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60605/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60605/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60606/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60606/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60607/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60607/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60608/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60608/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60609/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60609/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60610/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60610/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60611/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60611/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60612/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60613/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60613/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60614/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60614/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60615/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60615/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60616/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60616/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60617/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60618/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60618/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60619/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60620/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60620/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60621/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60621/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60622/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60622/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60623/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60623/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60624/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60624/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60625/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60625/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60626/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60626/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60627/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60627/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60628/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60628/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60629/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60629/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60630/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60630/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60630/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60631/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60631/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60632/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60632/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60632/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60633/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60634/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60634/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60635/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60635/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60635/study2/view2_frontal.jpg
#   inflating: ./data/train/patient60636/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60636/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60636/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60637/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60637/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60638/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60638/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60638/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60638/study3/view2_lateral.jpg
#   inflating: ./data/train/patient60639/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60639/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60639/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60640/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60640/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60641/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60641/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60642/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60642/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60643/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60644/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60644/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60645/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60645/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60645/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60646/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60647/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60647/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60647/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60648/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60648/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60649/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60649/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60650/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60650/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60651/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60651/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60652/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60652/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60653/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60653/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60654/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60654/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60655/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60655/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60656/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60656/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60656/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60656/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60656/study4/view1_frontal.jpg
#   inflating: ./data/train/patient60657/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60657/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60657/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60658/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60658/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60658/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60659/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60659/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60660/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60660/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60661/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60661/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60662/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60662/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60663/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60663/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60664/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60664/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60665/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60665/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60666/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60666/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60667/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60667/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60668/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60668/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60669/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60669/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60670/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60670/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60671/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60671/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60672/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60672/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60673/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60673/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60674/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60674/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60674/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60675/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60675/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60676/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60676/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60677/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60677/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60678/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60678/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60679/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60679/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60679/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60680/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60681/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60681/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60682/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60682/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60683/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60683/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60684/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60684/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60685/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60685/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60685/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60686/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60686/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60687/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60687/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60688/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60688/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60689/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60689/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60690/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60690/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60691/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60692/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60692/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60693/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60693/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60694/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60695/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60695/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60695/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60696/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60696/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60697/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60698/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60698/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60699/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60699/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60700/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60701/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60701/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60701/study2/view2_lateral.jpg
#   inflating: ./data/train/patient60702/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60702/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60703/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60703/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60704/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60704/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60704/study1/view3_lateral.jpg
#   inflating: ./data/train/patient60705/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60706/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60706/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60707/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60707/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60708/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60708/study1/view2_lateral.jpg
#   inflating: ./data/train/patient60709/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60710/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60711/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60711/study1/view2_frontal.jpg
#   inflating: ./data/train/patient60712/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60712/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60713/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60714/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60715/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60716/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60717/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60718/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60719/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60720/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60721/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60722/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60722/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60723/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60724/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60725/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60726/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60727/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60728/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60729/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60730/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60731/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60732/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60733/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60734/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60735/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60736/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60737/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60738/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60739/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60740/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60741/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60742/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60742/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60743/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60744/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60745/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60746/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60747/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60747/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60748/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60749/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60750/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60751/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60752/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60753/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60753/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60754/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60755/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60756/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60756/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60757/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60757/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60758/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60759/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60760/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60761/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60762/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60763/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60764/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60765/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60766/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60767/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60768/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60769/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60770/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60771/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60772/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60773/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60774/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60775/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60775/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60776/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60777/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60778/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60779/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60780/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60781/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60782/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60783/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60784/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60785/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60786/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60787/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60788/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60789/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60790/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60791/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60792/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60792/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60793/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60794/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60795/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60796/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60797/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60797/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60798/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60799/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60800/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60801/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60802/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60803/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60804/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60805/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60806/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60807/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60808/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60809/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60810/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60811/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60811/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60811/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60812/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60813/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60814/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60815/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60816/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60817/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60818/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60819/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60820/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60821/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60822/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60823/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60824/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60824/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60825/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60826/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60827/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60827/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60828/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60829/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60830/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60831/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60832/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60833/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60834/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60835/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60836/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60837/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60838/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60838/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60839/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60840/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60841/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60842/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60843/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60844/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60844/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60845/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60846/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60847/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60848/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60849/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60850/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60851/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60852/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60853/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60854/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60855/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60856/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60857/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60858/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60859/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60860/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60861/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60861/study2/view1_frontal.jpg
#   inflating: ./data/train/patient60861/study3/view1_frontal.jpg
#   inflating: ./data/train/patient60861/study4/view1_frontal.jpg
#   inflating: ./data/train/patient60862/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60863/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60864/study1/view1_frontal.jpg
#   inflating: ./data/train/patient60865/study1/view1_frontal.jpg
# ...
#   inflating: ./data/train/patient64536/study1/view1_frontal.jpg
#   inflating: ./data/train/patient64536/study2/view1_frontal.jpg
#   inflating: ./data/train/patient64537/study1/view1_frontal.jpg
#   inflating: ./data/train/patient64537/study2/view1_frontal.jpg
#   inflating: ./data/train/patient64538/study1/view1_frontal.jpg
#   inflating: ./data/train/patient64539/study1/view1_frontal.jpg
#   inflating: ./data/train/patient64540/study1/view1_frontal.jpg
#   inflating: ./data/valid.csv
#   inflating: ./data/valid/patient64541/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64542/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64542/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64543/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64544/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64545/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64546/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64547/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64547/study1/view2_frontal.jpg
#   inflating: ./data/valid/patient64547/study1/view3_lateral.jpg
#   inflating: ./data/valid/patient64548/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64549/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64550/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64551/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64551/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64552/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64553/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64554/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64555/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64556/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64556/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64557/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64558/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64558/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64559/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64559/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64560/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64560/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64561/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64562/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64563/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64564/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64565/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64566/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64566/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64567/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64567/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64568/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64569/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64570/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64570/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64571/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64572/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64573/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64574/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64575/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64575/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64576/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64577/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64578/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64579/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64580/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64581/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64581/study1/view2_frontal.jpg
#   inflating: ./data/valid/patient64581/study1/view3_lateral.jpg
#   inflating: ./data/valid/patient64582/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64583/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64584/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64584/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64585/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64586/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64587/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64588/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64588/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64589/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64589/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64590/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64590/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64591/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64592/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64593/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64594/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64594/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64595/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64595/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64596/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64597/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64597/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64598/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64599/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64599/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64600/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64600/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64601/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64602/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64603/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64604/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64605/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64606/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64606/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64607/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64608/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64608/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64609/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64610/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64611/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64612/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64613/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64613/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64614/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64615/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64615/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64616/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64616/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64616/study1/view3_lateral.jpg
#   inflating: ./data/valid/patient64617/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64618/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64618/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64619/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64620/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64621/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64622/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64623/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64624/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64625/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64625/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64626/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64627/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64628/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64629/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64630/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64631/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64632/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64633/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64634/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64635/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64636/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64637/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64638/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64639/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64640/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64640/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64641/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64642/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64643/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64644/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64645/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64646/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64647/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64648/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64649/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64650/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64651/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64652/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64653/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64654/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64655/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64656/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64657/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64658/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64659/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64660/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64661/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64662/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64663/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64664/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64665/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64666/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64667/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64668/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64669/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64670/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64671/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64672/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64673/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64674/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64675/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64676/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64676/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64677/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64678/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64679/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64680/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64681/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64682/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64683/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64684/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64685/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64686/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64687/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64688/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64689/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64690/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64691/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64692/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64693/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64694/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64695/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64696/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64697/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64698/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64699/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64700/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64701/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64702/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64703/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64704/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64705/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64705/study1/view2_lateral.jpg
#   inflating: ./data/valid/patient64706/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64707/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64708/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64709/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64710/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64711/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64712/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64713/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64714/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64715/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64716/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64717/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64718/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64719/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64720/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64721/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64722/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64723/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64724/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64725/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64726/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64727/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64728/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64729/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64730/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64731/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64732/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64733/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64734/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64735/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64736/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64737/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64738/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64739/study1/view1_frontal.jpg
#   inflating: ./data/valid/patient64740/study1/view1_frontal.jpg

# %%
# !kaggle datasets download khanfashee/nih-chest-x-ray-14-224x224-resized
# Out:
# Dataset URL: https://www.kaggle.com/datasets/khanfashee/nih-chest-x-ray-14-224x224-resized
# License(s): CC0-1.0
# Downloading nih-chest-x-ray-14-224x224-resized.zip to /content/Few-Shot-Domain-Adaptation-for-Medical-Image-Classification
#  97% 2.23G/2.30G [00:01<00:00, 1.58GB/s]
# 100% 2.30G/2.30G [00:01<00:00, 1.66GB/s]

# %%
# !unzip nih-chest-x-ray-14-224x224-resized.zip -d ./data/nih/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/nih/images-224/images-224/00028897_017.png
#   inflating: ./data/nih/images-224/images-224/00028897_018.png
#   inflating: ./data/nih/images-224/images-224/00028897_019.png
#   inflating: ./data/nih/images-224/images-224/00028897_020.png
#   inflating: ./data/nih/images-224/images-224/00028898_000.png
#   inflating: ./data/nih/images-224/images-224/00028899_000.png
#   inflating: ./data/nih/images-224/images-224/00028899_001.png
#   inflating: ./data/nih/images-224/images-224/00028899_002.png
#   inflating: ./data/nih/images-224/images-224/00028900_000.png
#   inflating: ./data/nih/images-224/images-224/00028901_000.png
#   inflating: ./data/nih/images-224/images-224/00028901_001.png
#   inflating: ./data/nih/images-224/images-224/00028902_000.png
#   inflating: ./data/nih/images-224/images-224/00028902_001.png
#   inflating: ./data/nih/images-224/images-224/00028902_002.png
#   inflating: ./data/nih/images-224/images-224/00028902_003.png
#   inflating: ./data/nih/images-224/images-224/00028902_004.png
#   inflating: ./data/nih/images-224/images-224/00028902_005.png
#   inflating: ./data/nih/images-224/images-224/00028902_006.png
#   inflating: ./data/nih/images-224/images-224/00028902_007.png
#   inflating: ./data/nih/images-224/images-224/00028902_008.png
#   inflating: ./data/nih/images-224/images-224/00028903_000.png
#   inflating: ./data/nih/images-224/images-224/00028903_001.png
#   inflating: ./data/nih/images-224/images-224/00028903_002.png
#   inflating: ./data/nih/images-224/images-224/00028903_003.png
#   inflating: ./data/nih/images-224/images-224/00028903_004.png
#   inflating: ./data/nih/images-224/images-224/00028904_000.png
#   inflating: ./data/nih/images-224/images-224/00028905_000.png
#   inflating: ./data/nih/images-224/images-224/00028905_001.png
#   inflating: ./data/nih/images-224/images-224/00028906_000.png
#   inflating: ./data/nih/images-224/images-224/00028907_000.png
#   inflating: ./data/nih/images-224/images-224/00028908_000.png
#   inflating: ./data/nih/images-224/images-224/00028909_000.png
#   inflating: ./data/nih/images-224/images-224/00028909_001.png
#   inflating: ./data/nih/images-224/images-224/00028909_002.png
#   inflating: ./data/nih/images-224/images-224/00028910_000.png
#   inflating: ./data/nih/images-224/images-224/00028911_000.png
#   inflating: ./data/nih/images-224/images-224/00028911_001.png
#   inflating: ./data/nih/images-224/images-224/00028911_002.png
#   inflating: ./data/nih/images-224/images-224/00028911_003.png
#   inflating: ./data/nih/images-224/images-224/00028911_004.png
#   inflating: ./data/nih/images-224/images-224/00028911_005.png
#   inflating: ./data/nih/images-224/images-224/00028911_006.png
#   inflating: ./data/nih/images-224/images-224/00028911_007.png
#   inflating: ./data/nih/images-224/images-224/00028912_000.png
#   inflating: ./data/nih/images-224/images-224/00028912_001.png
#   inflating: ./data/nih/images-224/images-224/00028912_002.png
#   inflating: ./data/nih/images-224/images-224/00028912_003.png
#   inflating: ./data/nih/images-224/images-224/00028913_000.png
#   inflating: ./data/nih/images-224/images-224/00028913_001.png
#   inflating: ./data/nih/images-224/images-224/00028913_002.png
#   inflating: ./data/nih/images-224/images-224/00028914_000.png
#   inflating: ./data/nih/images-224/images-224/00028915_000.png
#   inflating: ./data/nih/images-224/images-224/00028916_000.png
#   inflating: ./data/nih/images-224/images-224/00028916_001.png
#   inflating: ./data/nih/images-224/images-224/00028916_002.png
#   inflating: ./data/nih/images-224/images-224/00028917_000.png
#   inflating: ./data/nih/images-224/images-224/00028918_000.png
#   inflating: ./data/nih/images-224/images-224/00028918_001.png
#   inflating: ./data/nih/images-224/images-224/00028918_002.png
#   inflating: ./data/nih/images-224/images-224/00028918_003.png
#   inflating: ./data/nih/images-224/images-224/00028918_004.png
#   inflating: ./data/nih/images-224/images-224/00028918_005.png
#   inflating: ./data/nih/images-224/images-224/00028918_006.png
#   inflating: ./data/nih/images-224/images-224/00028918_007.png
#   inflating: ./data/nih/images-224/images-224/00028919_000.png
#   inflating: ./data/nih/images-224/images-224/00028920_000.png
#   inflating: ./data/nih/images-224/images-224/00028920_001.png
#   inflating: ./data/nih/images-224/images-224/00028920_002.png
#   inflating: ./data/nih/images-224/images-224/00028920_003.png
#   inflating: ./data/nih/images-224/images-224/00028920_004.png
#   inflating: ./data/nih/images-224/images-224/00028921_000.png
#   inflating: ./data/nih/images-224/images-224/00028921_001.png
#   inflating: ./data/nih/images-224/images-224/00028922_000.png
#   inflating: ./data/nih/images-224/images-224/00028923_000.png
#   inflating: ./data/nih/images-224/images-224/00028923_001.png
#   inflating: ./data/nih/images-224/images-224/00028923_002.png
#   inflating: ./data/nih/images-224/images-224/00028923_003.png
#   inflating: ./data/nih/images-224/images-224/00028924_000.png
#   inflating: ./data/nih/images-224/images-224/00028924_001.png
#   inflating: ./data/nih/images-224/images-224/00028924_002.png
#   inflating: ./data/nih/images-224/images-224/00028924_003.png
#   inflating: ./data/nih/images-224/images-224/00028924_004.png
#   inflating: ./data/nih/images-224/images-224/00028924_005.png
#   inflating: ./data/nih/images-224/images-224/00028924_006.png
#   inflating: ./data/nih/images-224/images-224/00028924_007.png
#   inflating: ./data/nih/images-224/images-224/00028924_008.png
#   inflating: ./data/nih/images-224/images-224/00028924_009.png
#   inflating: ./data/nih/images-224/images-224/00028924_010.png
#   inflating: ./data/nih/images-224/images-224/00028924_011.png
#   inflating: ./data/nih/images-224/images-224/00028924_012.png
#   inflating: ./data/nih/images-224/images-224/00028925_000.png
#   inflating: ./data/nih/images-224/images-224/00028926_000.png
#   inflating: ./data/nih/images-224/images-224/00028926_001.png
#   inflating: ./data/nih/images-224/images-224/00028927_000.png
#   inflating: ./data/nih/images-224/images-224/00028927_001.png
#   inflating: ./data/nih/images-224/images-224/00028927_002.png
#   inflating: ./data/nih/images-224/images-224/00028928_000.png
#   inflating: ./data/nih/images-224/images-224/00028929_000.png
#   inflating: ./data/nih/images-224/images-224/00028930_000.png
#   inflating: ./data/nih/images-224/images-224/00028931_000.png
#   inflating: ./data/nih/images-224/images-224/00028932_000.png
#   inflating: ./data/nih/images-224/images-224/00028932_001.png
#   inflating: ./data/nih/images-224/images-224/00028933_000.png
#   inflating: ./data/nih/images-224/images-224/00028934_000.png
#   inflating: ./data/nih/images-224/images-224/00028934_001.png
#   inflating: ./data/nih/images-224/images-224/00028934_002.png
#   inflating: ./data/nih/images-224/images-224/00028935_000.png
#   inflating: ./data/nih/images-224/images-224/00028935_001.png
#   inflating: ./data/nih/images-224/images-224/00028936_000.png
#   inflating: ./data/nih/images-224/images-224/00028936_001.png
#   inflating: ./data/nih/images-224/images-224/00028937_000.png
#   inflating: ./data/nih/images-224/images-224/00028938_000.png
#   inflating: ./data/nih/images-224/images-224/00028939_000.png
#   inflating: ./data/nih/images-224/images-224/00028939_001.png
#   inflating: ./data/nih/images-224/images-224/00028939_002.png
#   inflating: ./data/nih/images-224/images-224/00028939_003.png
#   inflating: ./data/nih/images-224/images-224/00028939_004.png
#   inflating: ./data/nih/images-224/images-224/00028939_005.png
#   inflating: ./data/nih/images-224/images-224/00028939_006.png
#   inflating: ./data/nih/images-224/images-224/00028939_007.png
#   inflating: ./data/nih/images-224/images-224/00028939_008.png
#   inflating: ./data/nih/images-224/images-224/00028939_009.png
#   inflating: ./data/nih/images-224/images-224/00028939_010.png
#   inflating: ./data/nih/images-224/images-224/00028939_011.png
#   inflating: ./data/nih/images-224/images-224/00028939_012.png
#   inflating: ./data/nih/images-224/images-224/00028939_013.png
#   inflating: ./data/nih/images-224/images-224/00028939_014.png
#   inflating: ./data/nih/images-224/images-224/00028939_015.png
#   inflating: ./data/nih/images-224/images-224/00028939_016.png
#   inflating: ./data/nih/images-224/images-224/00028939_017.png
#   inflating: ./data/nih/images-224/images-224/00028939_018.png
#   inflating: ./data/nih/images-224/images-224/00028939_019.png
#   inflating: ./data/nih/images-224/images-224/00028939_020.png
#   inflating: ./data/nih/images-224/images-224/00028939_021.png
#   inflating: ./data/nih/images-224/images-224/00028940_000.png
#   inflating: ./data/nih/images-224/images-224/00028940_001.png
#   inflating: ./data/nih/images-224/images-224/00028940_002.png
#   inflating: ./data/nih/images-224/images-224/00028940_003.png
#   inflating: ./data/nih/images-224/images-224/00028940_004.png
#   inflating: ./data/nih/images-224/images-224/00028940_005.png
#   inflating: ./data/nih/images-224/images-224/00028941_000.png
#   inflating: ./data/nih/images-224/images-224/00028942_000.png
#   inflating: ./data/nih/images-224/images-224/00028943_000.png
#   inflating: ./data/nih/images-224/images-224/00028944_000.png
#   inflating: ./data/nih/images-224/images-224/00028945_000.png
#   inflating: ./data/nih/images-224/images-224/00028946_000.png
#   inflating: ./data/nih/images-224/images-224/00028947_000.png
#   inflating: ./data/nih/images-224/images-224/00028947_001.png
#   inflating: ./data/nih/images-224/images-224/00028948_000.png
#   inflating: ./data/nih/images-224/images-224/00028948_001.png
#   inflating: ./data/nih/images-224/images-224/00028948_002.png
#   inflating: ./data/nih/images-224/images-224/00028948_003.png
#   inflating: ./data/nih/images-224/images-224/00028948_004.png
#   inflating: ./data/nih/images-224/images-224/00028948_005.png
#   inflating: ./data/nih/images-224/images-224/00028949_000.png
#   inflating: ./data/nih/images-224/images-224/00028950_000.png
#   inflating: ./data/nih/images-224/images-224/00028951_000.png
#   inflating: ./data/nih/images-224/images-224/00028952_000.png
#   inflating: ./data/nih/images-224/images-224/00028953_000.png
#   inflating: ./data/nih/images-224/images-224/00028953_001.png
#   inflating: ./data/nih/images-224/images-224/00028954_000.png
#   inflating: ./data/nih/images-224/images-224/00028955_000.png
#   inflating: ./data/nih/images-224/images-224/00028956_000.png
#   inflating: ./data/nih/images-224/images-224/00028957_000.png
#   inflating: ./data/nih/images-224/images-224/00028957_001.png
#   inflating: ./data/nih/images-224/images-224/00028958_000.png
#   inflating: ./data/nih/images-224/images-224/00028958_001.png
#   inflating: ./data/nih/images-224/images-224/00028958_002.png
#   inflating: ./data/nih/images-224/images-224/00028958_003.png
#   inflating: ./data/nih/images-224/images-224/00028959_000.png
#   inflating: ./data/nih/images-224/images-224/00028960_000.png
#   inflating: ./data/nih/images-224/images-224/00028961_000.png
#   inflating: ./data/nih/images-224/images-224/00028961_001.png
#   inflating: ./data/nih/images-224/images-224/00028961_002.png
#   inflating: ./data/nih/images-224/images-224/00028961_003.png
#   inflating: ./data/nih/images-224/images-224/00028961_004.png
#   inflating: ./data/nih/images-224/images-224/00028961_005.png
#   inflating: ./data/nih/images-224/images-224/00028961_006.png
#   inflating: ./data/nih/images-224/images-224/00028961_007.png
#   inflating: ./data/nih/images-224/images-224/00028961_008.png
#   inflating: ./data/nih/images-224/images-224/00028962_000.png
#   inflating: ./data/nih/images-224/images-224/00028963_000.png
#   inflating: ./data/nih/images-224/images-224/00028963_001.png
#   inflating: ./data/nih/images-224/images-224/00028963_002.png
#   inflating: ./data/nih/images-224/images-224/00028963_003.png
#   inflating: ./data/nih/images-224/images-224/00028963_004.png
#   inflating: ./data/nih/images-224/images-224/00028964_000.png
#   inflating: ./data/nih/images-224/images-224/00028964_001.png
#   inflating: ./data/nih/images-224/images-224/00028965_000.png
#   inflating: ./data/nih/images-224/images-224/00028966_000.png
#   inflating: ./data/nih/images-224/images-224/00028967_000.png
#   inflating: ./data/nih/images-224/images-224/00028968_000.png
#   inflating: ./data/nih/images-224/images-224/00028969_000.png
#   inflating: ./data/nih/images-224/images-224/00028970_000.png
#   inflating: ./data/nih/images-224/images-224/00028970_001.png
#   inflating: ./data/nih/images-224/images-224/00028971_000.png
#   inflating: ./data/nih/images-224/images-224/00028971_001.png
#   inflating: ./data/nih/images-224/images-224/00028971_002.png
#   inflating: ./data/nih/images-224/images-224/00028972_000.png
#   inflating: ./data/nih/images-224/images-224/00028973_000.png
#   inflating: ./data/nih/images-224/images-224/00028974_000.png
#   inflating: ./data/nih/images-224/images-224/00028974_001.png
#   inflating: ./data/nih/images-224/images-224/00028974_002.png
#   inflating: ./data/nih/images-224/images-224/00028974_003.png
#   inflating: ./data/nih/images-224/images-224/00028974_004.png
#   inflating: ./data/nih/images-224/images-224/00028974_005.png
#   inflating: ./data/nih/images-224/images-224/00028974_006.png
#   inflating: ./data/nih/images-224/images-224/00028974_007.png
#   inflating: ./data/nih/images-224/images-224/00028974_008.png
#   inflating: ./data/nih/images-224/images-224/00028974_009.png
#   inflating: ./data/nih/images-224/images-224/00028974_010.png
#   inflating: ./data/nih/images-224/images-224/00028974_011.png
#   inflating: ./data/nih/images-224/images-224/00028974_012.png
#   inflating: ./data/nih/images-224/images-224/00028974_013.png
#   inflating: ./data/nih/images-224/images-224/00028974_014.png
#   inflating: ./data/nih/images-224/images-224/00028974_015.png
#   inflating: ./data/nih/images-224/images-224/00028974_016.png
#   inflating: ./data/nih/images-224/images-224/00028974_017.png
#   inflating: ./data/nih/images-224/images-224/00028974_018.png
#   inflating: ./data/nih/images-224/images-224/00028974_019.png
#   inflating: ./data/nih/images-224/images-224/00028974_020.png
#   inflating: ./data/nih/images-224/images-224/00028974_021.png
#   inflating: ./data/nih/images-224/images-224/00028974_022.png
#   inflating: ./data/nih/images-224/images-224/00028974_023.png
#   inflating: ./data/nih/images-224/images-224/00028974_024.png
#   inflating: ./data/nih/images-224/images-224/00028975_000.png
#   inflating: ./data/nih/images-224/images-224/00028975_001.png
#   inflating: ./data/nih/images-224/images-224/00028975_002.png
#   inflating: ./data/nih/images-224/images-224/00028976_000.png
#   inflating: ./data/nih/images-224/images-224/00028977_000.png
#   inflating: ./data/nih/images-224/images-224/00028977_001.png
#   inflating: ./data/nih/images-224/images-224/00028977_002.png
#   inflating: ./data/nih/images-224/images-224/00028978_000.png
#   inflating: ./data/nih/images-224/images-224/00028979_000.png
#   inflating: ./data/nih/images-224/images-224/00028980_000.png
#   inflating: ./data/nih/images-224/images-224/00028980_001.png
#   inflating: ./data/nih/images-224/images-224/00028981_000.png
#   inflating: ./data/nih/images-224/images-224/00028982_000.png
#   inflating: ./data/nih/images-224/images-224/00028983_000.png
#   inflating: ./data/nih/images-224/images-224/00028984_000.png
#   inflating: ./data/nih/images-224/images-224/00028985_000.png
#   inflating: ./data/nih/images-224/images-224/00028986_000.png
#   inflating: ./data/nih/images-224/images-224/00028987_000.png
#   inflating: ./data/nih/images-224/images-224/00028987_001.png
#   inflating: ./data/nih/images-224/images-224/00028987_002.png
#   inflating: ./data/nih/images-224/images-224/00028987_003.png
#   inflating: ./data/nih/images-224/images-224/00028987_004.png
#   inflating: ./data/nih/images-224/images-224/00028987_005.png
#   inflating: ./data/nih/images-224/images-224/00028987_006.png
#   inflating: ./data/nih/images-224/images-224/00028987_007.png
#   inflating: ./data/nih/images-224/images-224/00028987_008.png
#   inflating: ./data/nih/images-224/images-224/00028987_009.png
#   inflating: ./data/nih/images-224/images-224/00028987_010.png
#   inflating: ./data/nih/images-224/images-224/00028987_011.png
#   inflating: ./data/nih/images-224/images-224/00028987_012.png
#   inflating: ./data/nih/images-224/images-224/00028987_013.png
#   inflating: ./data/nih/images-224/images-224/00028987_014.png
#   inflating: ./data/nih/images-224/images-224/00028987_015.png
#   inflating: ./data/nih/images-224/images-224/00028987_016.png
#   inflating: ./data/nih/images-224/images-224/00028987_017.png
#   inflating: ./data/nih/images-224/images-224/00028987_018.png
#   inflating: ./data/nih/images-224/images-224/00028988_000.png
#   inflating: ./data/nih/images-224/images-224/00028989_000.png
#   inflating: ./data/nih/images-224/images-224/00028990_000.png
#   inflating: ./data/nih/images-224/images-224/00028991_000.png
#   inflating: ./data/nih/images-224/images-224/00028992_000.png
#   inflating: ./data/nih/images-224/images-224/00028992_001.png
#   inflating: ./data/nih/images-224/images-224/00028993_000.png
#   inflating: ./data/nih/images-224/images-224/00028993_001.png
#   inflating: ./data/nih/images-224/images-224/00028994_000.png
#   inflating: ./data/nih/images-224/images-224/00028995_000.png
#   inflating: ./data/nih/images-224/images-224/00028995_001.png
#   inflating: ./data/nih/images-224/images-224/00028995_002.png
#   inflating: ./data/nih/images-224/images-224/00028995_003.png
#   inflating: ./data/nih/images-224/images-224/00028995_004.png
#   inflating: ./data/nih/images-224/images-224/00028995_005.png
#   inflating: ./data/nih/images-224/images-224/00028995_006.png
#   inflating: ./data/nih/images-224/images-224/00028995_007.png
#   inflating: ./data/nih/images-224/images-224/00028995_008.png
#   inflating: ./data/nih/images-224/images-224/00028996_000.png
#   inflating: ./data/nih/images-224/images-224/00028996_001.png
#   inflating: ./data/nih/images-224/images-224/00028996_002.png
#   inflating: ./data/nih/images-224/images-224/00028996_003.png
#   inflating: ./data/nih/images-224/images-224/00028996_004.png
#   inflating: ./data/nih/images-224/images-224/00028996_005.png
#   inflating: ./data/nih/images-224/images-224/00028996_006.png
#   inflating: ./data/nih/images-224/images-224/00028996_007.png
#   inflating: ./data/nih/images-224/images-224/00028996_008.png
#   inflating: ./data/nih/images-224/images-224/00028996_009.png
#   inflating: ./data/nih/images-224/images-224/00028996_010.png
#   inflating: ./data/nih/images-224/images-224/00028997_000.png
#   inflating: ./data/nih/images-224/images-224/00028998_000.png
#   inflating: ./data/nih/images-224/images-224/00028999_000.png
#   inflating: ./data/nih/images-224/images-224/00028999_001.png
#   inflating: ./data/nih/images-224/images-224/00029000_000.png
#   inflating: ./data/nih/images-224/images-224/00029001_000.png
#   inflating: ./data/nih/images-224/images-224/00029002_000.png
#   inflating: ./data/nih/images-224/images-224/00029003_000.png
#   inflating: ./data/nih/images-224/images-224/00029004_000.png
#   inflating: ./data/nih/images-224/images-224/00029005_000.png
#   inflating: ./data/nih/images-224/images-224/00029006_000.png
#   inflating: ./data/nih/images-224/images-224/00029006_001.png
#   inflating: ./data/nih/images-224/images-224/00029006_002.png
#   inflating: ./data/nih/images-224/images-224/00029007_000.png
#   inflating: ./data/nih/images-224/images-224/00029007_001.png
#   inflating: ./data/nih/images-224/images-224/00029007_002.png
#   inflating: ./data/nih/images-224/images-224/00029008_000.png
#   inflating: ./data/nih/images-224/images-224/00029009_000.png
#   inflating: ./data/nih/images-224/images-224/00029009_001.png
#   inflating: ./data/nih/images-224/images-224/00029009_002.png
#   inflating: ./data/nih/images-224/images-224/00029010_000.png
#   inflating: ./data/nih/images-224/images-224/00029011_000.png
#   inflating: ./data/nih/images-224/images-224/00029012_000.png
#   inflating: ./data/nih/images-224/images-224/00029013_000.png
#   inflating: ./data/nih/images-224/images-224/00029014_000.png
#   inflating: ./data/nih/images-224/images-224/00029015_000.png
#   inflating: ./data/nih/images-224/images-224/00029015_001.png
#   inflating: ./data/nih/images-224/images-224/00029016_000.png
#   inflating: ./data/nih/images-224/images-224/00029016_001.png
#   inflating: ./data/nih/images-224/images-224/00029016_002.png
#   inflating: ./data/nih/images-224/images-224/00029017_000.png
#   inflating: ./data/nih/images-224/images-224/00029017_001.png
#   inflating: ./data/nih/images-224/images-224/00029017_002.png
#   inflating: ./data/nih/images-224/images-224/00029017_003.png
#   inflating: ./data/nih/images-224/images-224/00029017_004.png
#   inflating: ./data/nih/images-224/images-224/00029017_005.png
#   inflating: ./data/nih/images-224/images-224/00029017_006.png
#   inflating: ./data/nih/images-224/images-224/00029018_000.png
#   inflating: ./data/nih/images-224/images-224/00029018_001.png
#   inflating: ./data/nih/images-224/images-224/00029019_000.png
#   inflating: ./data/nih/images-224/images-224/00029020_000.png
#   inflating: ./data/nih/images-224/images-224/00029021_000.png
#   inflating: ./data/nih/images-224/images-224/00029021_001.png
#   inflating: ./data/nih/images-224/images-224/00029022_000.png
#   inflating: ./data/nih/images-224/images-224/00029023_000.png
#   inflating: ./data/nih/images-224/images-224/00029024_000.png
#   inflating: ./data/nih/images-224/images-224/00029025_000.png
#   inflating: ./data/nih/images-224/images-224/00029025_001.png
#   inflating: ./data/nih/images-224/images-224/00029025_002.png
#   inflating: ./data/nih/images-224/images-224/00029025_003.png
#   inflating: ./data/nih/images-224/images-224/00029025_004.png
#   inflating: ./data/nih/images-224/images-224/00029025_005.png
#   inflating: ./data/nih/images-224/images-224/00029025_006.png
#   inflating: ./data/nih/images-224/images-224/00029026_000.png
#   inflating: ./data/nih/images-224/images-224/00029027_000.png
#   inflating: ./data/nih/images-224/images-224/00029028_000.png
#   inflating: ./data/nih/images-224/images-224/00029029_000.png
#   inflating: ./data/nih/images-224/images-224/00029030_000.png
#   inflating: ./data/nih/images-224/images-224/00029030_001.png
#   inflating: ./data/nih/images-224/images-224/00029031_000.png
#   inflating: ./data/nih/images-224/images-224/00029032_000.png
#   inflating: ./data/nih/images-224/images-224/00029033_000.png
#   inflating: ./data/nih/images-224/images-224/00029034_000.png
#   inflating: ./data/nih/images-224/images-224/00029035_000.png
#   inflating: ./data/nih/images-224/images-224/00029035_001.png
#   inflating: ./data/nih/images-224/images-224/00029035_002.png
#   inflating: ./data/nih/images-224/images-224/00029035_003.png
#   inflating: ./data/nih/images-224/images-224/00029035_004.png
#   inflating: ./data/nih/images-224/images-224/00029035_005.png
#   inflating: ./data/nih/images-224/images-224/00029035_006.png
#   inflating: ./data/nih/images-224/images-224/00029035_007.png
#   inflating: ./data/nih/images-224/images-224/00029035_008.png
#   inflating: ./data/nih/images-224/images-224/00029036_000.png
#   inflating: ./data/nih/images-224/images-224/00029037_000.png
#   inflating: ./data/nih/images-224/images-224/00029037_001.png
#   inflating: ./data/nih/images-224/images-224/00029038_000.png
#   inflating: ./data/nih/images-224/images-224/00029038_001.png
#   inflating: ./data/nih/images-224/images-224/00029039_000.png
#   inflating: ./data/nih/images-224/images-224/00029039_001.png
#   inflating: ./data/nih/images-224/images-224/00029039_002.png
#   inflating: ./data/nih/images-224/images-224/00029039_003.png
#   inflating: ./data/nih/images-224/images-224/00029039_004.png
#   inflating: ./data/nih/images-224/images-224/00029039_005.png
#   inflating: ./data/nih/images-224/images-224/00029039_006.png
#   inflating: ./data/nih/images-224/images-224/00029039_007.png
#   inflating: ./data/nih/images-224/images-224/00029039_008.png
#   inflating: ./data/nih/images-224/images-224/00029039_009.png
#   inflating: ./data/nih/images-224/images-224/00029039_010.png
#   inflating: ./data/nih/images-224/images-224/00029039_011.png
#   inflating: ./data/nih/images-224/images-224/00029039_012.png
#   inflating: ./data/nih/images-224/images-224/00029039_013.png
#   inflating: ./data/nih/images-224/images-224/00029039_014.png
#   inflating: ./data/nih/images-224/images-224/00029039_015.png
#   inflating: ./data/nih/images-224/images-224/00029039_016.png
#   inflating: ./data/nih/images-224/images-224/00029039_017.png
#   inflating: ./data/nih/images-224/images-224/00029039_018.png
#   inflating: ./data/nih/images-224/images-224/00029039_019.png
#   inflating: ./data/nih/images-224/images-224/00029039_020.png
#   inflating: ./data/nih/images-224/images-224/00029039_021.png
#   inflating: ./data/nih/images-224/images-224/00029039_022.png
#   inflating: ./data/nih/images-224/images-224/00029040_000.png
#   inflating: ./data/nih/images-224/images-224/00029041_000.png
#   inflating: ./data/nih/images-224/images-224/00029041_001.png
#   inflating: ./data/nih/images-224/images-224/00029041_002.png
#   inflating: ./data/nih/images-224/images-224/00029041_003.png
#   inflating: ./data/nih/images-224/images-224/00029041_004.png
#   inflating: ./data/nih/images-224/images-224/00029041_005.png
#   inflating: ./data/nih/images-224/images-224/00029041_006.png
#   inflating: ./data/nih/images-224/images-224/00029041_007.png
#   inflating: ./data/nih/images-224/images-224/00029041_008.png
#   inflating: ./data/nih/images-224/images-224/00029041_009.png
#   inflating: ./data/nih/images-224/images-224/00029041_010.png
#   inflating: ./data/nih/images-224/images-224/00029041_011.png
#   inflating: ./data/nih/images-224/images-224/00029041_012.png
#   inflating: ./data/nih/images-224/images-224/00029041_013.png
#   inflating: ./data/nih/images-224/images-224/00029041_014.png
#   inflating: ./data/nih/images-224/images-224/00029041_015.png
#   inflating: ./data/nih/images-224/images-224/00029041_016.png
#   inflating: ./data/nih/images-224/images-224/00029041_017.png
#   inflating: ./data/nih/images-224/images-224/00029041_018.png
#   inflating: ./data/nih/images-224/images-224/00029042_000.png
#   inflating: ./data/nih/images-224/images-224/00029043_000.png
#   inflating: ./data/nih/images-224/images-224/00029043_001.png
#   inflating: ./data/nih/images-224/images-224/00029043_002.png
#   inflating: ./data/nih/images-224/images-224/00029043_003.png
#   inflating: ./data/nih/images-224/images-224/00029044_000.png
#   inflating: ./data/nih/images-224/images-224/00029045_000.png
#   inflating: ./data/nih/images-224/images-224/00029046_000.png
#   inflating: ./data/nih/images-224/images-224/00029047_000.png
#   inflating: ./data/nih/images-224/images-224/00029048_000.png
#   inflating: ./data/nih/images-224/images-224/00029048_001.png
#   inflating: ./data/nih/images-224/images-224/00029049_000.png
#   inflating: ./data/nih/images-224/images-224/00029050_000.png
#   inflating: ./data/nih/images-224/images-224/00029051_000.png
#   inflating: ./data/nih/images-224/images-224/00029052_000.png
#   inflating: ./data/nih/images-224/images-224/00029052_001.png
#   inflating: ./data/nih/images-224/images-224/00029052_002.png
#   inflating: ./data/nih/images-224/images-224/00029052_003.png
#   inflating: ./data/nih/images-224/images-224/00029052_004.png
#   inflating: ./data/nih/images-224/images-224/00029052_005.png
#   inflating: ./data/nih/images-224/images-224/00029052_006.png
#   inflating: ./data/nih/images-224/images-224/00029052_007.png
#   inflating: ./data/nih/images-224/images-224/00029052_008.png
#   inflating: ./data/nih/images-224/images-224/00029052_009.png
#   inflating: ./data/nih/images-224/images-224/00029052_010.png
#   inflating: ./data/nih/images-224/images-224/00029052_011.png
#   inflating: ./data/nih/images-224/images-224/00029052_012.png
#   inflating: ./data/nih/images-224/images-224/00029052_013.png
#   inflating: ./data/nih/images-224/images-224/00029052_014.png
#   inflating: ./data/nih/images-224/images-224/00029052_015.png
#   inflating: ./data/nih/images-224/images-224/00029053_000.png
#   inflating: ./data/nih/images-224/images-224/00029054_000.png
#   inflating: ./data/nih/images-224/images-224/00029054_001.png
#   inflating: ./data/nih/images-224/images-224/00029054_002.png
#   inflating: ./data/nih/images-224/images-224/00029055_000.png
#   inflating: ./data/nih/images-224/images-224/00029056_000.png
#   inflating: ./data/nih/images-224/images-224/00029056_001.png
#   inflating: ./data/nih/images-224/images-224/00029056_002.png
#   inflating: ./data/nih/images-224/images-224/00029056_003.png
#   inflating: ./data/nih/images-224/images-224/00029056_004.png
#   inflating: ./data/nih/images-224/images-224/00029056_005.png
#   inflating: ./data/nih/images-224/images-224/00029056_006.png
#   inflating: ./data/nih/images-224/images-224/00029057_000.png
#   inflating: ./data/nih/images-224/images-224/00029058_000.png
#   inflating: ./data/nih/images-224/images-224/00029058_001.png
#   inflating: ./data/nih/images-224/images-224/00029058_002.png
#   inflating: ./data/nih/images-224/images-224/00029058_003.png
#   inflating: ./data/nih/images-224/images-224/00029058_004.png
#   inflating: ./data/nih/images-224/images-224/00029058_005.png
#   inflating: ./data/nih/images-224/images-224/00029059_000.png
#   inflating: ./data/nih/images-224/images-224/00029060_000.png
#   inflating: ./data/nih/images-224/images-224/00029061_000.png
#   inflating: ./data/nih/images-224/images-224/00029062_000.png
#   inflating: ./data/nih/images-224/images-224/00029063_000.png
#   inflating: ./data/nih/images-224/images-224/00029064_000.png
#   inflating: ./data/nih/images-224/images-224/00029065_000.png
#   inflating: ./data/nih/images-224/images-224/00029066_000.png
#   inflating: ./data/nih/images-224/images-224/00029067_000.png
#   inflating: ./data/nih/images-224/images-224/00029068_000.png
#   inflating: ./data/nih/images-224/images-224/00029069_000.png
#   inflating: ./data/nih/images-224/images-224/00029070_000.png
#   inflating: ./data/nih/images-224/images-224/00029071_000.png
#   inflating: ./data/nih/images-224/images-224/00029072_000.png
#   inflating: ./data/nih/images-224/images-224/00029072_001.png
#   inflating: ./data/nih/images-224/images-224/00029073_000.png
#   inflating: ./data/nih/images-224/images-224/00029074_000.png
#   inflating: ./data/nih/images-224/images-224/00029074_001.png
#   inflating: ./data/nih/images-224/images-224/00029074_002.png
#   inflating: ./data/nih/images-224/images-224/00029075_000.png
#   inflating: ./data/nih/images-224/images-224/00029075_001.png
#   inflating: ./data/nih/images-224/images-224/00029075_002.png
#   inflating: ./data/nih/images-224/images-224/00029075_003.png
#   inflating: ./data/nih/images-224/images-224/00029075_004.png
#   inflating: ./data/nih/images-224/images-224/00029075_005.png
#   inflating: ./data/nih/images-224/images-224/00029075_006.png
#   inflating: ./data/nih/images-224/images-224/00029075_007.png
#   inflating: ./data/nih/images-224/images-224/00029075_008.png
#   inflating: ./data/nih/images-224/images-224/00029075_009.png
#   inflating: ./data/nih/images-224/images-224/00029075_010.png
#   inflating: ./data/nih/images-224/images-224/00029075_011.png
#   inflating: ./data/nih/images-224/images-224/00029075_012.png
#   inflating: ./data/nih/images-224/images-224/00029075_013.png
#   inflating: ./data/nih/images-224/images-224/00029075_014.png
#   inflating: ./data/nih/images-224/images-224/00029075_015.png
#   inflating: ./data/nih/images-224/images-224/00029075_016.png
#   inflating: ./data/nih/images-224/images-224/00029075_017.png
#   inflating: ./data/nih/images-224/images-224/00029075_018.png
#   inflating: ./data/nih/images-224/images-224/00029076_000.png
#   inflating: ./data/nih/images-224/images-224/00029077_000.png
#   inflating: ./data/nih/images-224/images-224/00029078_000.png
#   inflating: ./data/nih/images-224/images-224/00029079_000.png
#   inflating: ./data/nih/images-224/images-224/00029080_000.png
#   inflating: ./data/nih/images-224/images-224/00029081_000.png
#   inflating: ./data/nih/images-224/images-224/00029081_001.png
#   inflating: ./data/nih/images-224/images-224/00029081_002.png
#   inflating: ./data/nih/images-224/images-224/00029082_000.png
#   inflating: ./data/nih/images-224/images-224/00029083_000.png
#   inflating: ./data/nih/images-224/images-224/00029084_000.png
#   inflating: ./data/nih/images-224/images-224/00029085_000.png
#   inflating: ./data/nih/images-224/images-224/00029086_000.png
#   inflating: ./data/nih/images-224/images-224/00029087_000.png
#   inflating: ./data/nih/images-224/images-224/00029088_000.png
#   inflating: ./data/nih/images-224/images-224/00029088_001.png
#   inflating: ./data/nih/images-224/images-224/00029088_002.png
#   inflating: ./data/nih/images-224/images-224/00029088_003.png
#   inflating: ./data/nih/images-224/images-224/00029088_004.png
#   inflating: ./data/nih/images-224/images-224/00029088_005.png
#   inflating: ./data/nih/images-224/images-224/00029088_006.png
#   inflating: ./data/nih/images-224/images-224/00029088_007.png
#   inflating: ./data/nih/images-224/images-224/00029088_008.png
#   inflating: ./data/nih/images-224/images-224/00029088_009.png
#   inflating: ./data/nih/images-224/images-224/00029088_010.png
#   inflating: ./data/nih/images-224/images-224/00029088_011.png
#   inflating: ./data/nih/images-224/images-224/00029088_012.png
#   inflating: ./data/nih/images-224/images-224/00029088_013.png
#   inflating: ./data/nih/images-224/images-224/00029088_014.png
#   inflating: ./data/nih/images-224/images-224/00029088_015.png
#   inflating: ./data/nih/images-224/images-224/00029088_016.png
#   inflating: ./data/nih/images-224/images-224/00029088_017.png
#   inflating: ./data/nih/images-224/images-224/00029088_018.png
#   inflating: ./data/nih/images-224/images-224/00029088_019.png
#   inflating: ./data/nih/images-224/images-224/00029088_020.png
#   inflating: ./data/nih/images-224/images-224/00029088_021.png
#   inflating: ./data/nih/images-224/images-224/00029088_022.png
#   inflating: ./data/nih/images-224/images-224/00029088_023.png
#   inflating: ./data/nih/images-224/images-224/00029088_024.png
#   inflating: ./data/nih/images-224/images-224/00029088_025.png
#   inflating: ./data/nih/images-224/images-224/00029088_026.png
#   inflating: ./data/nih/images-224/images-224/00029088_027.png
#   inflating: ./data/nih/images-224/images-224/00029088_028.png
#   inflating: ./data/nih/images-224/images-224/00029088_029.png
#   inflating: ./data/nih/images-224/images-224/00029089_000.png
#   inflating: ./data/nih/images-224/images-224/00029090_000.png
#   inflating: ./data/nih/images-224/images-224/00029091_000.png
#   inflating: ./data/nih/images-224/images-224/00029092_000.png
#   inflating: ./data/nih/images-224/images-224/00029093_000.png
#   inflating: ./data/nih/images-224/images-224/00029094_000.png
#   inflating: ./data/nih/images-224/images-224/00029095_000.png
#   inflating: ./data/nih/images-224/images-224/00029096_000.png
#   inflating: ./data/nih/images-224/images-224/00029097_000.png
#   inflating: ./data/nih/images-224/images-224/00029097_001.png
#   inflating: ./data/nih/images-224/images-224/00029097_002.png
#   inflating: ./data/nih/images-224/images-224/00029098_000.png
#   inflating: ./data/nih/images-224/images-224/00029099_000.png
#   inflating: ./data/nih/images-224/images-224/00029100_000.png
#   inflating: ./data/nih/images-224/images-224/00029101_000.png
#   inflating: ./data/nih/images-224/images-224/00029102_000.png
#   inflating: ./data/nih/images-224/images-224/00029102_001.png
#   inflating: ./data/nih/images-224/images-224/00029102_002.png
#   inflating: ./data/nih/images-224/images-224/00029102_003.png
#   inflating: ./data/nih/images-224/images-224/00029103_000.png
#   inflating: ./data/nih/images-224/images-224/00029104_000.png
#   inflating: ./data/nih/images-224/images-224/00029105_000.png
#   inflating: ./data/nih/images-224/images-224/00029105_001.png
#   inflating: ./data/nih/images-224/images-224/00029105_002.png
#   inflating: ./data/nih/images-224/images-224/00029105_003.png
#   inflating: ./data/nih/images-224/images-224/00029105_004.png
#   inflating: ./data/nih/images-224/images-224/00029105_005.png
#   inflating: ./data/nih/images-224/images-224/00029105_006.png
#   inflating: ./data/nih/images-224/images-224/00029105_007.png
#   inflating: ./data/nih/images-224/images-224/00029105_008.png
#   inflating: ./data/nih/images-224/images-224/00029105_009.png
#   inflating: ./data/nih/images-224/images-224/00029105_010.png
#   inflating: ./data/nih/images-224/images-224/00029105_011.png
#   inflating: ./data/nih/images-224/images-224/00029105_012.png
#   inflating: ./data/nih/images-224/images-224/00029105_013.png
#   inflating: ./data/nih/images-224/images-224/00029105_014.png
#   inflating: ./data/nih/images-224/images-224/00029105_015.png
#   inflating: ./data/nih/images-224/images-224/00029105_016.png
#   inflating: ./data/nih/images-224/images-224/00029105_017.png
#   inflating: ./data/nih/images-224/images-224/00029105_018.png
#   inflating: ./data/nih/images-224/images-224/00029105_019.png
#   inflating: ./data/nih/images-224/images-224/00029105_020.png
#   inflating: ./data/nih/images-224/images-224/00029105_021.png
#   inflating: ./data/nih/images-224/images-224/00029105_022.png
#   inflating: ./data/nih/images-224/images-224/00029105_023.png
#   inflating: ./data/nih/images-224/images-224/00029105_024.png
#   inflating: ./data/nih/images-224/images-224/00029105_025.png
#   inflating: ./data/nih/images-224/images-224/00029105_026.png
#   inflating: ./data/nih/images-224/images-224/00029105_027.png
#   inflating: ./data/nih/images-224/images-224/00029105_028.png
#   inflating: ./data/nih/images-224/images-224/00029105_029.png
#   inflating: ./data/nih/images-224/images-224/00029105_030.png
#   inflating: ./data/nih/images-224/images-224/00029106_000.png
#   inflating: ./data/nih/images-224/images-224/00029107_000.png
#   inflating: ./data/nih/images-224/images-224/00029107_001.png
#   inflating: ./data/nih/images-224/images-224/00029108_000.png
#   inflating: ./data/nih/images-224/images-224/00029108_001.png
#   inflating: ./data/nih/images-224/images-224/00029108_002.png
#   inflating: ./data/nih/images-224/images-224/00029108_003.png
#   inflating: ./data/nih/images-224/images-224/00029108_004.png
#   inflating: ./data/nih/images-224/images-224/00029108_005.png
#   inflating: ./data/nih/images-224/images-224/00029109_000.png
#   inflating: ./data/nih/images-224/images-224/00029110_000.png
#   inflating: ./data/nih/images-224/images-224/00029111_000.png
#   inflating: ./data/nih/images-224/images-224/00029112_000.png
#   inflating: ./data/nih/images-224/images-224/00029113_000.png
#   inflating: ./data/nih/images-224/images-224/00029114_000.png
#   inflating: ./data/nih/images-224/images-224/00029115_000.png
#   inflating: ./data/nih/images-224/images-224/00029115_001.png
#   inflating: ./data/nih/images-224/images-224/00029115_002.png
#   inflating: ./data/nih/images-224/images-224/00029116_000.png
#   inflating: ./data/nih/images-224/images-224/00029117_000.png
#   inflating: ./data/nih/images-224/images-224/00029118_000.png
#   inflating: ./data/nih/images-224/images-224/00029118_001.png
#   inflating: ./data/nih/images-224/images-224/00029118_002.png
#   inflating: ./data/nih/images-224/images-224/00029118_003.png
#   inflating: ./data/nih/images-224/images-224/00029118_004.png
#   inflating: ./data/nih/images-224/images-224/00029118_005.png
#   inflating: ./data/nih/images-224/images-224/00029118_006.png
#   inflating: ./data/nih/images-224/images-224/00029118_007.png
#   inflating: ./data/nih/images-224/images-224/00029118_008.png
#   inflating: ./data/nih/images-224/images-224/00029119_000.png
#   inflating: ./data/nih/images-224/images-224/00029120_000.png
#   inflating: ./data/nih/images-224/images-224/00029121_000.png
#   inflating: ./data/nih/images-224/images-224/00029121_001.png
#   inflating: ./data/nih/images-224/images-224/00029122_000.png
#   inflating: ./data/nih/images-224/images-224/00029123_000.png
#   inflating: ./data/nih/images-224/images-224/00029124_000.png
#   inflating: ./data/nih/images-224/images-224/00029124_001.png
#   inflating: ./data/nih/images-224/images-224/00029124_002.png
#   inflating: ./data/nih/images-224/images-224/00029125_000.png
#   inflating: ./data/nih/images-224/images-224/00029125_001.png
#   inflating: ./data/nih/images-224/images-224/00029126_000.png
#   inflating: ./data/nih/images-224/images-224/00029127_000.png
#   inflating: ./data/nih/images-224/images-224/00029128_000.png
#   inflating: ./data/nih/images-224/images-224/00029129_000.png
#   inflating: ./data/nih/images-224/images-224/00029129_001.png
#   inflating: ./data/nih/images-224/images-224/00029129_002.png
#   inflating: ./data/nih/images-224/images-224/00029129_003.png
#   inflating: ./data/nih/images-224/images-224/00029129_004.png
#   inflating: ./data/nih/images-224/images-224/00029129_005.png
#   inflating: ./data/nih/images-224/images-224/00029129_006.png
#   inflating: ./data/nih/images-224/images-224/00029129_007.png
#   inflating: ./data/nih/images-224/images-224/00029130_000.png
#   inflating: ./data/nih/images-224/images-224/00029131_000.png
#   inflating: ./data/nih/images-224/images-224/00029132_000.png
#   inflating: ./data/nih/images-224/images-224/00029133_000.png
#   inflating: ./data/nih/images-224/images-224/00029134_000.png
#   inflating: ./data/nih/images-224/images-224/00029134_001.png
#   inflating: ./data/nih/images-224/images-224/00029134_002.png
#   inflating: ./data/nih/images-224/images-224/00029134_003.png
#   inflating: ./data/nih/images-224/images-224/00029134_004.png
#   inflating: ./data/nih/images-224/images-224/00029135_000.png
#   inflating: ./data/nih/images-224/images-224/00029135_001.png
#   inflating: ./data/nih/images-224/images-224/00029135_002.png
#   inflating: ./data/nih/images-224/images-224/00029135_003.png
#   inflating: ./data/nih/images-224/images-224/00029135_004.png
#   inflating: ./data/nih/images-224/images-224/00029135_005.png
#   inflating: ./data/nih/images-224/images-224/00029135_006.png
#   inflating: ./data/nih/images-224/images-224/00029136_000.png
#   inflating: ./data/nih/images-224/images-224/00029136_001.png
#   inflating: ./data/nih/images-224/images-224/00029137_000.png
#   inflating: ./data/nih/images-224/images-224/00029138_000.png
#   inflating: ./data/nih/images-224/images-224/00029139_000.png
#   inflating: ./data/nih/images-224/images-224/00029140_000.png
#   inflating: ./data/nih/images-224/images-224/00029141_000.png
#   inflating: ./data/nih/images-224/images-224/00029142_000.png
#   inflating: ./data/nih/images-224/images-224/00029142_001.png
#   inflating: ./data/nih/images-224/images-224/00029142_002.png
#   inflating: ./data/nih/images-224/images-224/00029142_003.png
#   inflating: ./data/nih/images-224/images-224/00029142_004.png
#   inflating: ./data/nih/images-224/images-224/00029142_005.png
#   inflating: ./data/nih/images-224/images-224/00029142_006.png
#   inflating: ./data/nih/images-224/images-224/00029142_007.png
#   inflating: ./data/nih/images-224/images-224/00029142_008.png
#   inflating: ./data/nih/images-224/images-224/00029142_009.png
#   inflating: ./data/nih/images-224/images-224/00029142_010.png
#   inflating: ./data/nih/images-224/images-224/00029142_011.png
#   inflating: ./data/nih/images-224/images-224/00029143_000.png
#   inflating: ./data/nih/images-224/images-224/00029144_000.png
#   inflating: ./data/nih/images-224/images-224/00029144_001.png
#   inflating: ./data/nih/images-224/images-224/00029145_000.png
#   inflating: ./data/nih/images-224/images-224/00029146_000.png
#   inflating: ./data/nih/images-224/images-224/00029146_001.png
#   inflating: ./data/nih/images-224/images-224/00029146_002.png
#   inflating: ./data/nih/images-224/images-224/00029146_003.png
#   inflating: ./data/nih/images-224/images-224/00029146_004.png
#   inflating: ./data/nih/images-224/images-224/00029146_005.png
#   inflating: ./data/nih/images-224/images-224/00029146_006.png
#   inflating: ./data/nih/images-224/images-224/00029146_007.png
#   inflating: ./data/nih/images-224/images-224/00029146_008.png
#   inflating: ./data/nih/images-224/images-224/00029147_000.png
#   inflating: ./data/nih/images-224/images-224/00029147_001.png
#   inflating: ./data/nih/images-224/images-224/00029147_002.png
#   inflating: ./data/nih/images-224/images-224/00029148_000.png
#   inflating: ./data/nih/images-224/images-224/00029149_000.png
#   inflating: ./data/nih/images-224/images-224/00029150_000.png
#   inflating: ./data/nih/images-224/images-224/00029150_001.png
#   inflating: ./data/nih/images-224/images-224/00029150_002.png
#   inflating: ./data/nih/images-224/images-224/00029150_003.png
#   inflating: ./data/nih/images-224/images-224/00029151_000.png
#   inflating: ./data/nih/images-224/images-224/00029152_000.png
#   inflating: ./data/nih/images-224/images-224/00029152_001.png
#   inflating: ./data/nih/images-224/images-224/00029152_002.png
#   inflating: ./data/nih/images-224/images-224/00029152_003.png
#   inflating: ./data/nih/images-224/images-224/00029153_000.png
#   inflating: ./data/nih/images-224/images-224/00029153_001.png
#   inflating: ./data/nih/images-224/images-224/00029154_000.png
#   inflating: ./data/nih/images-224/images-224/00029155_000.png
#   inflating: ./data/nih/images-224/images-224/00029155_001.png
#   inflating: ./data/nih/images-224/images-224/00029155_002.png
#   inflating: ./data/nih/images-224/images-224/00029155_003.png
#   inflating: ./data/nih/images-224/images-224/00029156_000.png
#   inflating: ./data/nih/images-224/images-224/00029156_001.png
#   inflating: ./data/nih/images-224/images-224/00029156_002.png
#   inflating: ./data/nih/images-224/images-224/00029156_003.png
#   inflating: ./data/nih/images-224/images-224/00029156_004.png
#   inflating: ./data/nih/images-224/images-224/00029156_005.png
#   inflating: ./data/nih/images-224/images-224/00029156_006.png
#   inflating: ./data/nih/images-224/images-224/00029157_000.png
#   inflating: ./data/nih/images-224/images-224/00029158_000.png
#   inflating: ./data/nih/images-224/images-224/00029159_000.png
#   inflating: ./data/nih/images-224/images-224/00029159_001.png
#   inflating: ./data/nih/images-224/images-224/00029159_002.png
#   inflating: ./data/nih/images-224/images-224/00029159_003.png
#   inflating: ./data/nih/images-224/images-224/00029159_004.png
#   inflating: ./data/nih/images-224/images-224/00029159_005.png
#   inflating: ./data/nih/images-224/images-224/00029159_006.png
#   inflating: ./data/nih/images-224/images-224/00029159_007.png
#   inflating: ./data/nih/images-224/images-224/00029159_008.png
#   inflating: ./data/nih/images-224/images-224/00029159_009.png
#   inflating: ./data/nih/images-224/images-224/00029159_010.png
#   inflating: ./data/nih/images-224/images-224/00029159_011.png
#   inflating: ./data/nih/images-224/images-224/00029159_012.png
#   inflating: ./data/nih/images-224/images-224/00029159_013.png
#   inflating: ./data/nih/images-224/images-224/00029159_014.png
# ...
#   inflating: ./data/nih/images-224/images-224/00030650_001.png
#   inflating: ./data/nih/images-224/images-224/00030650_002.png
#   inflating: ./data/nih/images-224/images-224/00030650_003.png
#   inflating: ./data/nih/images-224/images-224/00030650_004.png
#   inflating: ./data/nih/images-224/images-224/00030650_005.png
#   inflating: ./data/nih/images-224/images-224/00030650_006.png
#   inflating: ./data/nih/images-224/images-224/00030650_007.png
#   inflating: ./data/nih/images-224/images-224/00030650_008.png
#   inflating: ./data/nih/images-224/images-224/00030650_009.png
#   inflating: ./data/nih/images-224/images-224/00030651_000.png
#   inflating: ./data/nih/images-224/images-224/00030651_001.png
#   inflating: ./data/nih/images-224/images-224/00030651_002.png
#   inflating: ./data/nih/images-224/images-224/00030651_003.png
#   inflating: ./data/nih/images-224/images-224/00030651_004.png
#   inflating: ./data/nih/images-224/images-224/00030651_005.png
#   inflating: ./data/nih/images-224/images-224/00030651_006.png
#   inflating: ./data/nih/images-224/images-224/00030651_007.png
#   inflating: ./data/nih/images-224/images-224/00030652_000.png
#   inflating: ./data/nih/images-224/images-224/00030652_001.png
#   inflating: ./data/nih/images-224/images-224/00030652_002.png
#   inflating: ./data/nih/images-224/images-224/00030652_003.png
#   inflating: ./data/nih/images-224/images-224/00030652_004.png
#   inflating: ./data/nih/images-224/images-224/00030652_005.png
#   inflating: ./data/nih/images-224/images-224/00030653_000.png
#   inflating: ./data/nih/images-224/images-224/00030654_000.png
#   inflating: ./data/nih/images-224/images-224/00030654_001.png
#   inflating: ./data/nih/images-224/images-224/00030654_002.png
#   inflating: ./data/nih/images-224/images-224/00030655_000.png
#   inflating: ./data/nih/images-224/images-224/00030656_000.png
#   inflating: ./data/nih/images-224/images-224/00030656_001.png
#   inflating: ./data/nih/images-224/images-224/00030657_000.png
#   inflating: ./data/nih/images-224/images-224/00030658_000.png
#   inflating: ./data/nih/images-224/images-224/00030659_000.png
#   inflating: ./data/nih/images-224/images-224/00030659_001.png
#   inflating: ./data/nih/images-224/images-224/00030660_000.png
#   inflating: ./data/nih/images-224/images-224/00030661_000.png
#   inflating: ./data/nih/images-224/images-224/00030662_000.png
#   inflating: ./data/nih/images-224/images-224/00030663_000.png
#   inflating: ./data/nih/images-224/images-224/00030664_000.png
#   inflating: ./data/nih/images-224/images-224/00030665_000.png
#   inflating: ./data/nih/images-224/images-224/00030666_000.png
#   inflating: ./data/nih/images-224/images-224/00030667_000.png
#   inflating: ./data/nih/images-224/images-224/00030668_000.png
#   inflating: ./data/nih/images-224/images-224/00030669_000.png
#   inflating: ./data/nih/images-224/images-224/00030670_000.png
#   inflating: ./data/nih/images-224/images-224/00030671_000.png
#   inflating: ./data/nih/images-224/images-224/00030672_000.png
#   inflating: ./data/nih/images-224/images-224/00030672_001.png
#   inflating: ./data/nih/images-224/images-224/00030672_002.png
#   inflating: ./data/nih/images-224/images-224/00030673_000.png
#   inflating: ./data/nih/images-224/images-224/00030674_000.png
#   inflating: ./data/nih/images-224/images-224/00030675_000.png
#   inflating: ./data/nih/images-224/images-224/00030676_000.png
#   inflating: ./data/nih/images-224/images-224/00030677_000.png
#   inflating: ./data/nih/images-224/images-224/00030678_000.png
#   inflating: ./data/nih/images-224/images-224/00030678_001.png
#   inflating: ./data/nih/images-224/images-224/00030679_000.png
#   inflating: ./data/nih/images-224/images-224/00030679_001.png
#   inflating: ./data/nih/images-224/images-224/00030679_002.png
#   inflating: ./data/nih/images-224/images-224/00030679_003.png
#   inflating: ./data/nih/images-224/images-224/00030680_000.png
#   inflating: ./data/nih/images-224/images-224/00030680_001.png
#   inflating: ./data/nih/images-224/images-224/00030681_000.png
#   inflating: ./data/nih/images-224/images-224/00030682_000.png
#   inflating: ./data/nih/images-224/images-224/00030682_001.png
#   inflating: ./data/nih/images-224/images-224/00030683_000.png
#   inflating: ./data/nih/images-224/images-224/00030683_001.png
#   inflating: ./data/nih/images-224/images-224/00030684_000.png
#   inflating: ./data/nih/images-224/images-224/00030685_000.png
#   inflating: ./data/nih/images-224/images-224/00030685_001.png
#   inflating: ./data/nih/images-224/images-224/00030686_000.png
#   inflating: ./data/nih/images-224/images-224/00030687_000.png
#   inflating: ./data/nih/images-224/images-224/00030688_000.png
#   inflating: ./data/nih/images-224/images-224/00030688_001.png
#   inflating: ./data/nih/images-224/images-224/00030689_000.png
#   inflating: ./data/nih/images-224/images-224/00030689_001.png
#   inflating: ./data/nih/images-224/images-224/00030689_002.png
#   inflating: ./data/nih/images-224/images-224/00030689_003.png
#   inflating: ./data/nih/images-224/images-224/00030689_004.png
#   inflating: ./data/nih/images-224/images-224/00030690_000.png
#   inflating: ./data/nih/images-224/images-224/00030691_000.png
#   inflating: ./data/nih/images-224/images-224/00030692_000.png
#   inflating: ./data/nih/images-224/images-224/00030693_000.png
#   inflating: ./data/nih/images-224/images-224/00030693_001.png
#   inflating: ./data/nih/images-224/images-224/00030694_000.png
#   inflating: ./data/nih/images-224/images-224/00030695_000.png
#   inflating: ./data/nih/images-224/images-224/00030695_001.png
#   inflating: ./data/nih/images-224/images-224/00030695_002.png
#   inflating: ./data/nih/images-224/images-224/00030695_003.png
#   inflating: ./data/nih/images-224/images-224/00030695_004.png
#   inflating: ./data/nih/images-224/images-224/00030696_000.png
#   inflating: ./data/nih/images-224/images-224/00030697_000.png
#   inflating: ./data/nih/images-224/images-224/00030698_000.png
#   inflating: ./data/nih/images-224/images-224/00030699_000.png
#   inflating: ./data/nih/images-224/images-224/00030700_000.png
#   inflating: ./data/nih/images-224/images-224/00030701_000.png
#   inflating: ./data/nih/images-224/images-224/00030701_001.png
#   inflating: ./data/nih/images-224/images-224/00030701_002.png
#   inflating: ./data/nih/images-224/images-224/00030702_000.png
#   inflating: ./data/nih/images-224/images-224/00030703_000.png
#   inflating: ./data/nih/images-224/images-224/00030703_001.png
#   inflating: ./data/nih/images-224/images-224/00030704_000.png
#   inflating: ./data/nih/images-224/images-224/00030705_000.png
#   inflating: ./data/nih/images-224/images-224/00030706_000.png
#   inflating: ./data/nih/images-224/images-224/00030707_000.png
#   inflating: ./data/nih/images-224/images-224/00030708_000.png
#   inflating: ./data/nih/images-224/images-224/00030709_000.png
#   inflating: ./data/nih/images-224/images-224/00030709_001.png
#   inflating: ./data/nih/images-224/images-224/00030709_002.png
#   inflating: ./data/nih/images-224/images-224/00030710_000.png
#   inflating: ./data/nih/images-224/images-224/00030711_000.png
#   inflating: ./data/nih/images-224/images-224/00030712_000.png
#   inflating: ./data/nih/images-224/images-224/00030713_000.png
#   inflating: ./data/nih/images-224/images-224/00030714_000.png
#   inflating: ./data/nih/images-224/images-224/00030715_000.png
#   inflating: ./data/nih/images-224/images-224/00030716_000.png
#   inflating: ./data/nih/images-224/images-224/00030717_000.png
#   inflating: ./data/nih/images-224/images-224/00030718_000.png
#   inflating: ./data/nih/images-224/images-224/00030719_000.png
#   inflating: ./data/nih/images-224/images-224/00030720_000.png
#   inflating: ./data/nih/images-224/images-224/00030720_001.png
#   inflating: ./data/nih/images-224/images-224/00030720_002.png
#   inflating: ./data/nih/images-224/images-224/00030720_003.png
#   inflating: ./data/nih/images-224/images-224/00030720_004.png
#   inflating: ./data/nih/images-224/images-224/00030721_000.png
#   inflating: ./data/nih/images-224/images-224/00030722_000.png
#   inflating: ./data/nih/images-224/images-224/00030723_000.png
#   inflating: ./data/nih/images-224/images-224/00030724_000.png
#   inflating: ./data/nih/images-224/images-224/00030725_000.png
#   inflating: ./data/nih/images-224/images-224/00030726_000.png
#   inflating: ./data/nih/images-224/images-224/00030727_000.png
#   inflating: ./data/nih/images-224/images-224/00030728_000.png
#   inflating: ./data/nih/images-224/images-224/00030729_000.png
#   inflating: ./data/nih/images-224/images-224/00030730_000.png
#   inflating: ./data/nih/images-224/images-224/00030731_000.png
#   inflating: ./data/nih/images-224/images-224/00030732_000.png
#   inflating: ./data/nih/images-224/images-224/00030733_000.png
#   inflating: ./data/nih/images-224/images-224/00030733_001.png
#   inflating: ./data/nih/images-224/images-224/00030733_002.png
#   inflating: ./data/nih/images-224/images-224/00030733_003.png
#   inflating: ./data/nih/images-224/images-224/00030733_004.png
#   inflating: ./data/nih/images-224/images-224/00030733_005.png
#   inflating: ./data/nih/images-224/images-224/00030733_006.png
#   inflating: ./data/nih/images-224/images-224/00030734_000.png
#   inflating: ./data/nih/images-224/images-224/00030735_000.png
#   inflating: ./data/nih/images-224/images-224/00030736_000.png
#   inflating: ./data/nih/images-224/images-224/00030737_000.png
#   inflating: ./data/nih/images-224/images-224/00030738_000.png
#   inflating: ./data/nih/images-224/images-224/00030739_000.png
#   inflating: ./data/nih/images-224/images-224/00030740_000.png
#   inflating: ./data/nih/images-224/images-224/00030740_001.png
#   inflating: ./data/nih/images-224/images-224/00030740_002.png
#   inflating: ./data/nih/images-224/images-224/00030741_000.png
#   inflating: ./data/nih/images-224/images-224/00030742_000.png
#   inflating: ./data/nih/images-224/images-224/00030743_000.png
#   inflating: ./data/nih/images-224/images-224/00030744_000.png
#   inflating: ./data/nih/images-224/images-224/00030745_000.png
#   inflating: ./data/nih/images-224/images-224/00030746_000.png
#   inflating: ./data/nih/images-224/images-224/00030747_000.png
#   inflating: ./data/nih/images-224/images-224/00030748_000.png
#   inflating: ./data/nih/images-224/images-224/00030749_000.png
#   inflating: ./data/nih/images-224/images-224/00030750_000.png
#   inflating: ./data/nih/images-224/images-224/00030751_000.png
#   inflating: ./data/nih/images-224/images-224/00030752_000.png
#   inflating: ./data/nih/images-224/images-224/00030753_000.png
#   inflating: ./data/nih/images-224/images-224/00030753_001.png
#   inflating: ./data/nih/images-224/images-224/00030753_002.png
#   inflating: ./data/nih/images-224/images-224/00030753_003.png
#   inflating: ./data/nih/images-224/images-224/00030753_004.png
#   inflating: ./data/nih/images-224/images-224/00030753_005.png
#   inflating: ./data/nih/images-224/images-224/00030753_006.png
#   inflating: ./data/nih/images-224/images-224/00030753_007.png
#   inflating: ./data/nih/images-224/images-224/00030753_008.png
#   inflating: ./data/nih/images-224/images-224/00030753_009.png
#   inflating: ./data/nih/images-224/images-224/00030753_010.png
#   inflating: ./data/nih/images-224/images-224/00030753_011.png
#   inflating: ./data/nih/images-224/images-224/00030753_012.png
#   inflating: ./data/nih/images-224/images-224/00030754_000.png
#   inflating: ./data/nih/images-224/images-224/00030755_000.png
#   inflating: ./data/nih/images-224/images-224/00030756_000.png
#   inflating: ./data/nih/images-224/images-224/00030757_000.png
#   inflating: ./data/nih/images-224/images-224/00030758_000.png
#   inflating: ./data/nih/images-224/images-224/00030759_000.png
#   inflating: ./data/nih/images-224/images-224/00030760_000.png
#   inflating: ./data/nih/images-224/images-224/00030761_000.png
#   inflating: ./data/nih/images-224/images-224/00030762_000.png
#   inflating: ./data/nih/images-224/images-224/00030763_000.png
#   inflating: ./data/nih/images-224/images-224/00030764_000.png
#   inflating: ./data/nih/images-224/images-224/00030765_000.png
#   inflating: ./data/nih/images-224/images-224/00030766_000.png
#   inflating: ./data/nih/images-224/images-224/00030767_000.png
#   inflating: ./data/nih/images-224/images-224/00030768_000.png
#   inflating: ./data/nih/images-224/images-224/00030769_000.png
#   inflating: ./data/nih/images-224/images-224/00030770_000.png
#   inflating: ./data/nih/images-224/images-224/00030770_001.png
#   inflating: ./data/nih/images-224/images-224/00030770_002.png
#   inflating: ./data/nih/images-224/images-224/00030771_000.png
#   inflating: ./data/nih/images-224/images-224/00030772_000.png
#   inflating: ./data/nih/images-224/images-224/00030772_001.png
#   inflating: ./data/nih/images-224/images-224/00030772_002.png
#   inflating: ./data/nih/images-224/images-224/00030773_000.png
#   inflating: ./data/nih/images-224/images-224/00030773_001.png
#   inflating: ./data/nih/images-224/images-224/00030774_000.png
#   inflating: ./data/nih/images-224/images-224/00030775_000.png
#   inflating: ./data/nih/images-224/images-224/00030776_000.png
#   inflating: ./data/nih/images-224/images-224/00030777_000.png
#   inflating: ./data/nih/images-224/images-224/00030778_000.png
#   inflating: ./data/nih/images-224/images-224/00030779_000.png
#   inflating: ./data/nih/images-224/images-224/00030780_000.png
#   inflating: ./data/nih/images-224/images-224/00030781_000.png
#   inflating: ./data/nih/images-224/images-224/00030782_000.png
#   inflating: ./data/nih/images-224/images-224/00030783_000.png
#   inflating: ./data/nih/images-224/images-224/00030784_000.png
#   inflating: ./data/nih/images-224/images-224/00030785_000.png
#   inflating: ./data/nih/images-224/images-224/00030786_000.png
#   inflating: ./data/nih/images-224/images-224/00030786_001.png
#   inflating: ./data/nih/images-224/images-224/00030786_002.png
#   inflating: ./data/nih/images-224/images-224/00030786_003.png
#   inflating: ./data/nih/images-224/images-224/00030786_004.png
#   inflating: ./data/nih/images-224/images-224/00030786_005.png
#   inflating: ./data/nih/images-224/images-224/00030786_006.png
#   inflating: ./data/nih/images-224/images-224/00030786_007.png
#   inflating: ./data/nih/images-224/images-224/00030787_000.png
#   inflating: ./data/nih/images-224/images-224/00030788_000.png
#   inflating: ./data/nih/images-224/images-224/00030789_000.png
#   inflating: ./data/nih/images-224/images-224/00030790_000.png
#   inflating: ./data/nih/images-224/images-224/00030791_000.png
#   inflating: ./data/nih/images-224/images-224/00030791_001.png
#   inflating: ./data/nih/images-224/images-224/00030792_000.png
#   inflating: ./data/nih/images-224/images-224/00030792_001.png
#   inflating: ./data/nih/images-224/images-224/00030793_000.png
#   inflating: ./data/nih/images-224/images-224/00030794_000.png
#   inflating: ./data/nih/images-224/images-224/00030795_000.png
#   inflating: ./data/nih/images-224/images-224/00030796_000.png
#   inflating: ./data/nih/images-224/images-224/00030797_000.png
#   inflating: ./data/nih/images-224/images-224/00030798_000.png
#   inflating: ./data/nih/images-224/images-224/00030799_000.png
#   inflating: ./data/nih/images-224/images-224/00030800_000.png
#   inflating: ./data/nih/images-224/images-224/00030801_000.png
#   inflating: ./data/nih/images-224/images-224/00030801_001.png
#   inflating: ./data/nih/images-224/images-224/00030802_000.png
#   inflating: ./data/nih/images-224/images-224/00030803_000.png
#   inflating: ./data/nih/images-224/images-224/00030804_000.png
#   inflating: ./data/nih/images-224/images-224/00030805_000.png
#   inflating: ./data/nih/pretrained_model.h5
#   inflating: ./data/nih/test_list_NIH.txt
#   inflating: ./data/nih/train_val_list_NIH.txt

# %%
import os
import shutil
import pandas as pd

# -------------------------------------------------------
# Directory structure
# -------------------------------------------------------
DATA_ROOT = "./data"
NIH_ROOT = f"{DATA_ROOT}/nih"
IMG_DIR = f"{NIH_ROOT}/images"   # final images folder

os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(NIH_ROOT, exist_ok=True)
os.makedirs(IMG_DIR, exist_ok=True)

print("Directory structure ready.")

# -------------------------------------------------------
# Move 224x224 images into a clean folder: nih/images/
# -------------------------------------------------------
SRC_IMG_DIR = f"{NIH_ROOT}/images-224"

if os.path.exists(SRC_IMG_DIR):
    print("Copying 224x224 images... (may take a few minutes)")
    for fname in os.listdir(SRC_IMG_DIR):
        src = os.path.join(SRC_IMG_DIR, fname)
        dst = os.path.join(IMG_DIR, fname)
        if os.path.isfile(src):
            shutil.copy(src, dst)

    print("Images copied successfully into:", IMG_DIR)
else:
    print("ERROR: images-224 folder not found.")


# -------------------------------------------------------
# Ensure metadata CSV files exist
# -------------------------------------------------------
meta_files = [
    "Data_Entry_2017.csv",
    "BBox_List_2017_Official_NIH.csv",
    "train_val_list_NIH.txt",
    "test_list_NIH.txt",
]

for f in meta_files:
    path = os.path.join(NIH_ROOT, f)
    if not os.path.exists(path):
        print(f"ERROR: Missing file -> {f}")

print("Metadata files found.")

# -------------------------------------------------------
# Create train/val/test splits from NIH official text lists
# -------------------------------------------------------
def create_split_csv(list_file, output_csv):
    df_meta = pd.read_csv(f"{NIH_ROOT}/Data_Entry_2017.csv")

    with open(list_file, "r") as f:
        names = [line.strip() for line in f if line.strip()]

    df_filtered = df_meta[df_meta["Image Index"].isin(names)]
    df_filtered.to_csv(output_csv, index=False)

    print(f"{output_csv} created with {len(df_filtered)} samples")


# TRAIN + VAL combined
create_split_csv(
    f"{NIH_ROOT}/train_val_list_NIH.txt",
    f"{NIH_ROOT}/nih_trainval.csv"
)

# TEST set
create_split_csv(
    f"{NIH_ROOT}/test_list_NIH.txt",
    f"{NIH_ROOT}/nih_test.csv"
)


# -------------------------------------------------------
# Split train_val into train/val (90/10)
# -------------------------------------------------------
df_trainval = pd.read_csv(f"{NIH_ROOT}/nih_trainval.csv")

df_val = df_trainval.sample(frac=0.1, random_state=42)
df_train = df_trainval.drop(df_val.index)

df_train.to_csv(f"{NIH_ROOT}/nih_train.csv", index=False)
df_val.to_csv(f"{NIH_ROOT}/nih_val.csv", index=False)

print("Train / Val split completed.")
print("Train:", len(df_train))
print("Val:", len(df_val))
print("Test:", len(pd.read_csv(f'{NIH_ROOT}/nih_test.csv')))
# Out:
# Directory structure ready.
# Copying 224x224 images... (may take a few minutes)
# Images copied successfully into: ./data/nih/images
# Metadata files found.
# ./data/nih/nih_trainval.csv created with 86524 samples
# ./data/nih/nih_test.csv created with 25596 samples
# Train / Val split completed.
# Train: 77872
# Val: 8652
# Test: 25596

# %%
# Configure paths (modify as needed)
DATA_ROOT = './data'
CHEXPERT_TRAIN = f'{DATA_ROOT}/chexpert_train.csv'
CHEXPERT_VAL = f'{DATA_ROOT}/chexpert_val.csv'
NIH_TRAIN = f'{DATA_ROOT}/nih/nih_train.csv'
NIH_VAL = f'{DATA_ROOT}/nih/nih_val.csv'
NIH_TEST = f'{DATA_ROOT}/nih/nih_test.csv'

# Create checkpoint directory
# !mkdir -p checkpoints logs

# %%
# Verify datasets
print("Checking dataset files...")
for csv_path in [CHEXPERT_TRAIN, CHEXPERT_VAL, NIH_TRAIN, NIH_VAL]:
    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
        print(f"✓ {csv_path}: {len(df)} samples")
    else:
        print(f"✗ {csv_path}: NOT FOUND")
# Out:
# Checking dataset files...
# ✓ ./data/chexpert_train.csv: 223414 samples
# ✓ ./data/chexpert_val.csv: 234 samples
# ✓ ./data/nih/nih_train.csv: 77872 samples
# ✓ ./data/nih/nih_val.csv: 8652 samples

# %% [markdown]
# ## 3. Configuration and Utilities

# %%
# Base configuration
config = Config(
    data_root=DATA_ROOT,
    img_size=224,
    num_classes=14,
    batch_size=32,
    num_workers=4,
    backbone='vit_base_patch16_224',
    pretrained=True,
    epochs=15,
    lr=1e-4,
    weight_decay=1e-4,
    optimizer='adamw',
    mixed_precision=True,
    gradient_checkpointing=True,
    few_shot_k=50,
    checkpoint_dir='./checkpoints',
    use_wandb=False,
    seed=42
)

set_seed(config.seed)
print("Configuration:")
print(f"  Backbone: {config.backbone}")
print(f"  Batch size: {config.batch_size}")
print(f"  Epochs: {config.epochs}")
print(f"  Learning rate: {config.lr}")
print(f"  Mixed precision: {config.mixed_precision}")
print(f"  Gradient checkpointing: {config.gradient_checkpointing}")
# Out:
# Configuration:
#   Backbone: vit_base_patch16_224
#   Batch size: 32
#   Epochs: 15
#   Learning rate: 0.0001
#   Mixed precision: True
#   Gradient checkpointing: True

# %% [markdown]
# ## 4. Experiment 1: Baseline ViT on Source Domain (CheXpert)
#
# Train a standard Vision Transformer on the source domain without any adaptation.

# %%
# Load CheXpert datasets
train_ds = SimpleMedicalDataset(CHEXPERT_TRAIN, DATA_ROOT, transform=get_transforms(config.img_size, True))
val_ds = SimpleMedicalDataset(CHEXPERT_VAL, DATA_ROOT, transform=get_transforms(config.img_size, False))

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=config.batch_size, shuffle=True,
                                           num_workers=config.num_workers, pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=config.batch_size, shuffle=False,
                                         num_workers=config.num_workers, pin_memory=True)

print(f"Train batches: {len(train_loader)}")
print(f"Val batches: {len(val_loader)}")
# Out:
# Train batches: 6982
# Val batches: 8

# %%
# Reload datasets module with path fix
import importlib
import data.datasets
importlib.reload(data.datasets)
from data.datasets import SimpleMedicalDataset, get_transforms, sample_few_shot_indices
print("✓ Dataset module reloaded with path fix")
# Out:
# ✓ Dataset module reloaded with path fix

# %%
# Recreate datasets with fixed paths
train_ds = SimpleMedicalDataset(CHEXPERT_TRAIN, DATA_ROOT, transform=get_transforms(config.img_size, True))
val_ds = SimpleMedicalDataset(CHEXPERT_VAL, DATA_ROOT, transform=get_transforms(config.img_size, False))

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=config.batch_size, shuffle=True,
                                           num_workers=config.num_workers, pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=config.batch_size, shuffle=False,
                                         num_workers=config.num_workers, pin_memory=True)

print(f"✓ Data loaders recreated")
print(f"Train batches: {len(train_loader)}")
print(f"Val batches: {len(val_loader)}")

# Test loading one batch
try:
    test_batch = next(iter(val_loader))
    print(f"✓ Successfully loaded test batch: {test_batch['image'].shape}")
except Exception as e:
    print(f"✗ Error loading batch: {e}")
# Out:
# ✓ Data loaders recreated
# Train batches: 6982
# Val batches: 8
# ✓ Successfully loaded test batch: torch.Size([32, 3, 224, 224])

# %%
# Build baseline ViT model
baseline_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=config.pretrained)

# Enable gradient checkpointing
if hasattr(baseline_model.backbone, 'set_grad_checkpointing'):
    baseline_model.backbone.set_grad_checkpointing(True)

params = count_parameters(baseline_model)
print(f"Total parameters: {params['total']:,}")
print(f"Trainable parameters: {params['trainable']:,}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Total parameters: 85,809,422
# Trainable parameters: 85,809,422

# %%
# Force reload updated modules
import importlib
import train.trainer
importlib.reload(train.trainer)
from train.trainer import LitModel
print("✓ Modules reloaded")
# Out:
# ✓ Modules reloaded

# %%
# Setup Lightning trainer
lit_baseline = LitModel(baseline_model, config)

checkpoint_callback = ModelCheckpoint(
    dirpath='./checkpoints/baseline_vit',
    filename='best-{epoch:02d}-{val/auc:.4f}',
    monitor='val/auc',
    mode='max',
    save_top_k=3
)

early_stop = EarlyStopping(monitor='val/auc', patience=10, mode='max', verbose=True)

trainer_baseline = pl.Trainer(
    max_epochs=config.epochs,
    accelerator='gpu',
    devices=-1,  # Use all available GPUs
    # precision=16 if config.mixed_precision else 32,
    precision='16-mixed' if config.mixed_precision else 32,
    callbacks=[checkpoint_callback, early_stop],
    gradient_clip_val=1.0,
    log_every_n_steps=10
)

print("🚀 Training baseline ViT on CheXpert...")
trainer_baseline.fit(lit_baseline, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# 🚀 Training baseline ViT on CheXpert...
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:231: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type              | Params | Mode
# --------------------------------------------------------
# 0 | model     | ViTWrapper        | 85.8 M | train
# 1 | criterion | BCEWithLogitsLoss | 0      | train
# --------------------------------------------------------
# 85.8 M    Trainable params
# 0         Non-trainable params
# 85.8 M    Total params
# 343.238   Total estimated model params size (MB)
# 279       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 32. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 10. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# INFO:pytorch_lightning.callbacks.early_stopping:Metric val/auc improved. New best score: 0.752
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.callbacks.early_stopping:Metric val/auc improved by 0.040 >= min_delta = 0.0. New best score: 0.793
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.callbacks.early_stopping:Metric val/auc improved by 0.016 >= min_delta = 0.0. New best score: 0.809
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.callbacks.early_stopping:Monitored metric val/auc did not improve in the last 10 records. Best score: 0.809. Signaling Trainer to stop.

# %%
# import os
# from google.colab import files

# directory_to_zip = "/content/Few-Shot-Domain-Adaptation-for-Medical-Image-Classification/data"
# output_zip_name = "data.zip"

# # Change current working directory to the parent of the directory_to_zip to zip it correctly
# # This makes the paths inside the zip file relative to 'data/'
# current_dir = os.getcwd()
# os.chdir(os.path.dirname(directory_to_zip))

# # Zip the directory
# !zip -r "{output_zip_name}" "{os.path.basename(directory_to_zip)}"

# # Change back to the original directory
# os.chdir(current_dir)

# # Move the zip file to the current working directory for easier download
# if os.path.exists(os.path.join(os.path.dirname(directory_to_zip), output_zip_name)):
#     os.rename(os.path.join(os.path.dirname(directory_to_zip), output_zip_name), output_zip_name)

# # Download the zipped file
# print(f"\nZipping and downloading '{os.path.basename(directory_to_zip)}' as '{output_zip_name}'...")
# files.download(output_zip_name)

# %%
# Save baseline checkpoint
torch.save({
    'model_state_dict': baseline_model.state_dict(),
    'config': config
}, './checkpoints/baseline_vit_source.pth')

print(f"✓ Baseline model saved")
print(f"Best val AUC: {checkpoint_callback.best_model_score:.4f}")
# Out:
# ✓ Baseline model saved
# Best val AUC: 0.8090

# %% [markdown]
# ## 5. Experiment 2: Few-Shot LoRA Adaptation (CheXpert → NIH)
#
# Apply LoRA to adapt the baseline model to NIH dataset with limited samples.

# %%
# Load NIH target dataset
nih_train_full = SimpleMedicalDataset(NIH_TRAIN, DATA_ROOT, transform=get_transforms(config.img_size, True))
nih_val = SimpleMedicalDataset(NIH_VAL, DATA_ROOT, transform=get_transforms(config.img_size, False))

# Sample few-shot subset
few_shot_indices = sample_few_shot_indices(nih_train_full, k_per_class=config.few_shot_k, seed=config.seed)
print(f"Few-shot sampling: {len(few_shot_indices)} samples (k={config.few_shot_k} per class)")

nih_train_fewshot = Subset(nih_train_full, few_shot_indices)

train_loader_nih = torch.utils.data.DataLoader(nih_train_fewshot, batch_size=config.batch_size,
                                                shuffle=True, num_workers=config.num_workers, pin_memory=True)
val_loader_nih = torch.utils.data.DataLoader(nih_val, batch_size=config.batch_size,
                                              shuffle=False, num_workers=config.num_workers, pin_memory=True)
# Out:
# Few-shot sampling: 350 samples (k=50 per class)

# %%
# Load baseline checkpoint and apply LoRA
lora_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=False)
checkpoint = torch.load('./checkpoints/baseline_vit_source.pth', weights_only=False)
lora_model.load_state_dict(checkpoint['model_state_dict'])
print("✓ Loaded baseline checkpoint")

# Apply LoRA
apply_lora_to_model(lora_model, r=8, alpha=32.0)

# Freeze original parameters
for name, param in lora_model.named_parameters():
    if 'lora_' not in name:
        param.requires_grad = False

lora_params = count_parameters(lora_model)
print(f"\nLoRA model parameters:")
print(f"  Total: {lora_params['total']:,}")
print(f"  Trainable: {lora_params['trainable']:,}")
print(f"  Efficiency: {100.0 * lora_params['trainable'] / lora_params['total']:.2f}% trainable")
# Out:
# ✓ Loaded baseline checkpoint
#
# LoRA model parameters:
#   Total: 86,995,326
#   Trainable: 1,185,904
#   Efficiency: 1.36% trainable

# %%
# Check NIH dataset structure
print("Checking NIH CSV structure...")
if os.path.exists(NIH_TRAIN):
    nih_df = pd.read_csv(NIH_TRAIN)
    print(f"NIH columns: {list(nih_df.columns[:10])}")  # First 10 columns
    print(f"NIH shape: {nih_df.shape}")
else:
    print("NIH train CSV not found!")
# Out:
# Checking NIH CSV structure...
# NIH columns: ['Image Index', 'Finding Labels', 'Follow-up #', 'Patient ID', 'Patient Age', 'Patient Gender', 'View Position', 'OriginalImage[Width', 'Height]', 'OriginalImagePixelSpacing[x']
# NIH shape: (77872, 12)

# %%
# Check NIH directory structure
print("Checking NIH directory structure...")
# !ls -la ./data/nih/ 2>/dev/null || echo "NIH directory structure:"
# !find ./data/nih -type f -name "*.png" | head -5 2>/dev/null || echo "Searching for NIH images..."
# !ls ./data/ | grep -i image 2>/dev/null || ls ./data/
# Out:
# Checking NIH directory structure...
# total 52832
# drwxr-xr-x 4 root root     4096 Nov 25 12:56 .
# drwxr-xr-x 7 root root     4096 Nov 25 12:57 ..
# -rw-r--r-- 1 root root    92416 Jul  8  2020 BBox_List_2017_Official_NIH.csv
# -rw-r--r-- 1 root root  8659561 Jul  8  2020 Data_Entry_2017.csv
# drwxr-xr-x 2 root root     4096 Nov 25 12:56 images
# drwxr-xr-x 3 root root     4096 Nov 25 12:56 images-224
# -rw-r--r-- 1 root root  1917431 Nov 25 12:56 nih_test.csv
# -rw-r--r-- 1 root root  5549863 Nov 25 12:56 nih_train.csv
# -rw-r--r-- 1 root root  6168271 Nov 25 12:56 nih_trainval.csv
# -rw-r--r-- 1 root root   618570 Nov 25 12:56 nih_val.csv
# -rw-r--r-- 1 root root 29148608 Jul  8  2020 pretrained_model.h5
# -rw-r--r-- 1 root root   435131 Jul  8  2020 test_list_NIH.txt
# -rw-r--r-- 1 root root  1470907 Jul  8  2020 train_val_list_NIH.txt
# ./data/nih/images-224/images-224/00000001_000.png
# ./data/nih/images-224/images-224/00000001_001.png
# ./data/nih/images-224/images-224/00000002_000.png
# ./data/nih/images-224/images-224/00000003_000.png
# ./data/nih/images-224/images-224/00000003_001.png
# chexpert_train.csv  datasets.py  __pycache__  valid
# chexpert_val.csv    nih		 train

# %%
# Reload dataset module with auto-detect path column fix
import importlib
import data.datasets
importlib.reload(data.datasets)
from data.datasets import SimpleMedicalDataset, get_transforms, sample_few_shot_indices
print("✓ Dataset module reloaded with path column auto-detection")
# Out:
# ✓ Dataset module reloaded with path column auto-detection

# %%
# Recreate NIH datasets with fixed loader
# NIH images are in ./data/nih/images-224/images-224/
NIH_IMG_ROOT = './data/nih/images-224/images-224'

print(f"Using NIH image root: {NIH_IMG_ROOT}")

nih_train_full = SimpleMedicalDataset(NIH_TRAIN, NIH_IMG_ROOT, transform=get_transforms(config.img_size, True))
nih_val = SimpleMedicalDataset(NIH_VAL, NIH_IMG_ROOT, transform=get_transforms(config.img_size, False))

# Sample few-shot subset
few_shot_indices = sample_few_shot_indices(nih_train_full, k_per_class=config.few_shot_k, seed=config.seed)
print(f"✓ Few-shot sampling: {len(few_shot_indices)} samples (k={config.few_shot_k} per class)")

nih_train_fewshot = Subset(nih_train_full, few_shot_indices)

train_loader_nih = torch.utils.data.DataLoader(nih_train_fewshot, batch_size=config.batch_size,
                                                shuffle=True, num_workers=config.num_workers, pin_memory=True)
val_loader_nih = torch.utils.data.DataLoader(nih_val, batch_size=config.batch_size,
                                              shuffle=False, num_workers=config.num_workers, pin_memory=True)

print(f"✓ NIH data loaders created")
print(f"Train batches: {len(train_loader_nih)}")
print(f"Val batches: {len(val_loader_nih)}")

# Test loading one batch
try:
    test_batch = next(iter(val_loader_nih))
    print(f"✓ Successfully loaded NIH batch: {test_batch['image'].shape}")
    print(f"✓ All systems ready for training!")
except Exception as e:
    print(f"✗ Error loading NIH batch: {e}")
    # Show a sample path for debugging
    sample_row = nih_val.df.iloc[0]
    print(f"Sample image index: {sample_row[nih_val.path_col]}")
    print(f"Expected path: {os.path.join(NIH_IMG_ROOT, str(sample_row[nih_val.path_col]))}")
# Out:
# Using NIH image root: ./data/nih/images-224/images-224
# ✓ Few-shot sampling: 350 samples (k=50 per class)
# ✓ NIH data loaders created
# Train batches: 11
# Val batches: 271
# ✓ Successfully loaded NIH batch: torch.Size([32, 3, 224, 224])
# ✓ All systems ready for training!

# %%
# Set num_workers=0 for all experiments to avoid worker crashes in Colab
SAFE_NUM_WORKERS = 0
print(f"⚠️  Using num_workers={SAFE_NUM_WORKERS} for all experiments to prevent DataLoader crashes")
# Out:
# ⚠️  Using num_workers=0 for all experiments to prevent DataLoader crashes

# %%
# Load baseline checkpoint and apply LoRA
lora_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=False)
checkpoint = torch.load('./checkpoints/baseline_vit_source.pth', weights_only=False)
lora_model.load_state_dict(checkpoint['model_state_dict'])
print("✓ Loaded baseline checkpoint")

# Apply LoRA
apply_lora_to_model(lora_model, r=8, alpha=32.0)

# Freeze original parameters
for name, param in lora_model.named_parameters():
    if 'lora_' not in name:
        param.requires_grad = False

lora_params = count_parameters(lora_model)
print(f"\nLoRA model parameters:")
print(f"  Total: {lora_params['total']:,}")
print(f"  Trainable: {lora_params['trainable']:,}")
print(f"  Efficiency: {100.0 * lora_params['trainable'] / lora_params['total']:.2f}% trainable")
# Out:
# ✓ Loaded baseline checkpoint
#
# LoRA model parameters:
#   Total: 86,995,326
#   Trainable: 1,185,904
#   Efficiency: 1.36% trainable

# %%
# Train with LoRA
lit_lora = LitModel(lora_model, config)

checkpoint_callback_lora = ModelCheckpoint(
    dirpath='./checkpoints/lora_adaptation',
    filename='best-{epoch:02d}-{val/auc:.4f}',
    monitor='val/auc',
    mode='max',
    save_top_k=3
)

trainer_lora = pl.Trainer(
    max_epochs=config.epochs,
    accelerator='gpu',
    devices=-1,
    # precision=16 if config.mixed_precision else 32,
    precision='16-mixed' if config.mixed_precision else 32,
    callbacks=[checkpoint_callback_lora, EarlyStopping(monitor='val/auc', patience=10, mode='max')],
    gradient_clip_val=1.0
)

print("🚀 Training with LoRA adaptation...")
trainer_lora.fit(lit_lora, train_dataloaders=train_loader_nih, val_dataloaders=val_loader_nih)

print(f"✓ LoRA training complete")
print(f"Best val AUC: {checkpoint_callback_lora.best_model_score:.4f}")

# %% [markdown]
# ## 6. Experiment 3: Few-Shot Adapter Adaptation

# %%
# Load baseline and apply adapters
adapter_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=False)
checkpoint = torch.load('./checkpoints/baseline_vit_source.pth', weights_only=False)
adapter_model.load_state_dict(checkpoint['model_state_dict'])

# Attach adapters
attach_adapter_to_vit(adapter_model.backbone, adapter_dim=64)

# Freeze backbone
for name, param in adapter_model.named_parameters():
    if 'adapter' not in name and 'classifier' not in name:
        param.requires_grad = False

adapter_params = count_parameters(adapter_model)
print(f"Adapter model - Trainable: {adapter_params['trainable']:,} ({100.0 * adapter_params['trainable'] / adapter_params['total']:.2f}%)")

# %%
# Train with adapters
lit_adapter = LitModel(adapter_model, config)

checkpoint_callback_adapter = ModelCheckpoint(
    dirpath='./checkpoints/adapter_adaptation',
    filename='best-{epoch:02d}-{val/auc:.4f}',
    monitor='val/auc',
    mode='max'
)

trainer_adapter = pl.Trainer(
    max_epochs=config.epochs,
    accelerator='gpu',
    devices=-1,
    # precision=16,
    precision='16-mixed',
    callbacks=[checkpoint_callback_adapter, EarlyStopping(monitor='val/auc', patience=10, mode='max')]
)

print("🚀 Training with Adapter adaptation...")
trainer_adapter.fit(lit_adapter, train_dataloaders=train_loader_nih, val_dataloaders=val_loader_nih)
print(f"Best val AUC: {checkpoint_callback_adapter.best_model_score:.4f}")

# %% [markdown]
# ## 7. Experiment 4: Few-Shot Prompt Tuning

# %%
# Load baseline and apply prompt tuning
prompt_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=False)
checkpoint = torch.load('./checkpoints/baseline_vit_source.pth', weights_only=False)
prompt_model.load_state_dict(checkpoint['model_state_dict'])

# Attach visual prompts
attach_visual_prompt_to_vit(prompt_model.backbone, prompt_tokens=10)

# Freeze everything except prompts and classifier
for name, param in prompt_model.named_parameters():
    if 'visual_prompt' not in name and 'classifier' not in name:
        param.requires_grad = False

prompt_params = count_parameters(prompt_model)
print(f"Prompt model - Trainable: {prompt_params['trainable']:,} ({100.0 * prompt_params['trainable'] / prompt_params['total']:.2f}%)")

# %%
# Reload prompts module with attn_mask fix
import importlib
import prompts.prompt_tuning
importlib.reload(prompts.prompt_tuning)
from prompts.prompt_tuning import attach_visual_prompt_to_vit
print("✓ Prompts module reloaded with attn_mask fix")

# %%
# Recreate prompt model with fixed module
prompt_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=False)
checkpoint = torch.load('./checkpoints/baseline_vit_source.pth', weights_only=False)
prompt_model.load_state_dict(checkpoint['model_state_dict'])
print("✓ Loaded baseline checkpoint")

# Attach visual prompts with fixed function
attach_visual_prompt_to_vit(prompt_model.backbone, prompt_tokens=10)

# Freeze everything except prompts and classifier
for name, param in prompt_model.named_parameters():
    if 'visual_prompt' not in name and 'classifier' not in name:
        param.requires_grad = False

prompt_params = count_parameters(prompt_model)
print(f"✓ Prompt model recreated")
print(f"  Trainable: {prompt_params['trainable']:,} ({100.0 * prompt_params['trainable'] / prompt_params['total']:.2f}%)")

# %%
# Reload prompts module with positional embedding fix
import importlib
import prompts.prompt_tuning
importlib.reload(prompts.prompt_tuning)
from prompts.prompt_tuning import attach_visual_prompt_to_vit
print("✓ Prompts module reloaded with positional embedding fix")

# %%
# Recreate prompt model with corrected positional embedding handling
prompt_model = ViTWrapper(model_name=config.backbone, num_classes=config.num_classes, pretrained=False)
checkpoint = torch.load('./checkpoints/baseline_vit_source.pth', weights_only=False)
prompt_model.load_state_dict(checkpoint['model_state_dict'])
print("✓ Loaded baseline checkpoint")

# Attach visual prompts with fixed function (pos_embed added BEFORE prompts)
attach_visual_prompt_to_vit(prompt_model.backbone, prompt_tokens=10)

# Freeze everything except prompts and classifier
for name, param in prompt_model.named_parameters():
    if 'visual_prompt' not in name and 'classifier' not in name:
        param.requires_grad = False

prompt_params = count_parameters(prompt_model)
print(f"✓ Prompt model recreated with corrected forward_features")
print(f"  Trainable: {prompt_params['trainable']:,} ({100.0 * prompt_params['trainable'] / prompt_params['total']:.2f}%)")

# %%
# Recreate Lightning module with the new prompt model
lit_prompt = LitModel(prompt_model, config)
print("✓ Lightning module recreated with updated prompt model")

# %%
# Debug: Test forward pass with a sample batch
print("Testing forward pass...")
test_batch = next(iter(val_loader_nih))
test_imgs = test_batch['image']
print(f"Input shape: {test_imgs.shape}")

prompt_model.eval()
with torch.no_grad():
    try:
        # Test backbone forward_features
        if hasattr(prompt_model.backbone, 'forward_features'):
            features = prompt_model.backbone.forward_features(test_imgs[:2])  # Test with 2 samples
            print(f"Features shape from forward_features: {features.shape}")

        # Test full model forward
        output = prompt_model(test_imgs[:2])
        print(f"Output shape from full model: {output.shape}")
        print(f"✓ Forward pass successful!")
    except Exception as e:
        print(f"✗ Forward pass failed: {e}")
        import traceback
        traceback.print_exc()

# %%
# Train with prompt tuning
lit_prompt = LitModel(prompt_model, config)

checkpoint_callback_prompt = ModelCheckpoint(
    dirpath='./checkpoints/prompt_adaptation',
    filename='best-{epoch:02d}-{val/auc:.4f}',
    monitor='val/auc',
    mode='max'
)

trainer_prompt = pl.Trainer(
    max_epochs=config.epochs,
    accelerator='gpu',
    devices=-1,
    # precision=16,
    precision='16-mixed',
    callbacks=[checkpoint_callback_prompt, EarlyStopping(monitor='val/auc', patience=10, mode='max')]
)

print("Training with Prompt Tuning...")
trainer_prompt.fit(lit_prompt, train_dataloaders=train_loader_nih, val_dataloaders=val_loader_nih)
print(f"Best val AUC: {checkpoint_callback_prompt.best_model_score:.4f}")

# %% [markdown]
# ## 8. Experiment 5: CNN Baselines

# %%
# ResNet-50 baseline with reduced workers
resnet_model = build_cnn('resnet50', num_classes=config.num_classes, pretrained=True)
lit_resnet = LitModel(resnet_model, config)

# Recreate data loaders with fewer workers to avoid memory issues
train_loader_nih_cnn = torch.utils.data.DataLoader(
    nih_train_fewshot, batch_size=config.batch_size,
    shuffle=True, num_workers=0, pin_memory=False  # num_workers=0 to avoid worker crashes
)
val_loader_nih_cnn = torch.utils.data.DataLoader(
    nih_val, batch_size=config.batch_size,
    shuffle=False, num_workers=0, pin_memory=False
)

trainer_resnet = pl.Trainer(
    max_epochs=config.epochs,
    accelerator='gpu',
    devices=-1,
    precision='16-mixed',
    callbacks=[ModelCheckpoint(dirpath='./checkpoints/resnet50', monitor='val/auc', mode='max')]
)

print("🚀 Training ResNet-50 baseline...")
trainer_resnet.fit(lit_resnet, train_dataloaders=train_loader_nih_cnn, val_dataloaders=val_loader_nih_cnn)

# %%
# Clean up memory before CNN baselines
import gc
import torch

# Clear CUDA cache
torch.cuda.empty_cache()
gc.collect()

# Reduce number of workers for CNN models to avoid memory issues
CNN_NUM_WORKERS = 2  # Reduced from 4

print("✓ Memory cleaned, using reduced worker count for CNN models")

# %%
# DenseNet-121 baseline with reduced workers
densenet_model = build_cnn('densenet121', num_classes=config.num_classes, pretrained=True)
lit_densenet = LitModel(densenet_model, config)

trainer_densenet = pl.Trainer(
    max_epochs=config.epochs,
    accelerator='gpu',
    devices=-1,
    precision='16-mixed',
    callbacks=[ModelCheckpoint(dirpath='./checkpoints/densenet121', monitor='val/auc', mode='max')]
)

print("🚀 Training DenseNet-121 baseline...")
trainer_densenet.fit(lit_densenet, train_dataloaders=train_loader_nih_cnn, val_dataloaders=val_loader_nih_cnn)

# %% [markdown]
# ## 9. Results Comparison and Visualization

# %%
# Collect results
results = {
    'Baseline ViT': checkpoint_callback.best_model_score.item(),
    'LoRA': checkpoint_callback_lora.best_model_score.item(),
    'Adapter': checkpoint_callback_adapter.best_model_score.item(),
    'Prompt Tuning': checkpoint_callback_prompt.best_model_score.item(),
}

# Parameter efficiency
param_counts = {
    'Baseline ViT': params['trainable'],
    'LoRA': lora_params['trainable'],
    'Adapter': adapter_params['trainable'],
    'Prompt Tuning': prompt_params['trainable'],
}

# Create comparison DataFrame
comparison_df = pd.DataFrame({
    'Method': list(results.keys()),
    'Val AUC': list(results.values()),
    'Trainable Params': list(param_counts.values())
})

comparison_df['Param Efficiency (%)'] = 100.0 * comparison_df['Trainable Params'] / params['total']
comparison_df = comparison_df.sort_values('Val AUC', ascending=False)

print("\n" + "="*70)
print("FINAL RESULTS COMPARISON")
print("="*70)
print(comparison_df.to_string(index=False))
print("="*70)

# %%
# Visualization
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# AUC comparison
axes[0].bar(comparison_df['Method'], comparison_df['Val AUC'], color=['blue', 'green', 'orange', 'red'])
axes[0].set_ylabel('Validation AUC', fontsize=12)
axes[0].set_title('Performance Comparison', fontsize=14, fontweight='bold')
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', alpha=0.3)

# Parameter efficiency
axes[1].bar(comparison_df['Method'], comparison_df['Param Efficiency (%)'], color=['blue', 'green', 'orange', 'red'])
axes[1].set_ylabel('Trainable Parameters (%)', fontsize=12)
axes[1].set_title('Parameter Efficiency', fontsize=14, fontweight='bold')
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('results_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("\n✓ Results saved to results_comparison.png")

# %% [markdown]
# ## 10. Test Set Evaluation with Confidence Intervals

# %%
# Load test dataset
if os.path.exists(NIH_TEST):
    # Use NIH_IMG_ROOT for test set (same as train/val)
    nih_test = SimpleMedicalDataset(NIH_TEST, NIH_IMG_ROOT, transform=get_transforms(config.img_size, False))
    test_loader = torch.utils.data.DataLoader(nih_test, batch_size=config.batch_size,
                                               shuffle=False, num_workers=0, pin_memory=False)

    # Evaluate best LoRA model
    print("Evaluating LoRA model on test set...")
    test_results = trainer_lora.test(lit_lora, dataloaders=test_loader)

    # Get predictions for bootstrap CI
    lora_model.cuda()
    lora_model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in test_loader:
            imgs = batch['image'].cuda()
            labels = batch['labels'].numpy()
            logits = lora_model(imgs)
            preds = torch.sigmoid(logits).cpu().numpy()
            all_preds.append(preds)
            all_labels.append(labels)

    all_preds = np.vstack(all_preds)
    all_labels = np.vstack(all_labels)

    # Compute metrics with CI
    from functools import partial
    auc_fn = partial(compute_metrics, thr=0.5)
    ci_results = bootstrap_confidence_interval(all_preds, all_labels,
                                                lambda p, l: compute_metrics(p, l)['auc_roc'],
                                                n_bootstrap=1000)

    print("\n" + "="*70)
    print("TEST SET RESULTS (LoRA Model)")
    print("="*70)
    print(f"AUC-ROC: {ci_results['mean']:.4f} (95% CI: [{ci_results['ci_lower']:.4f}, {ci_results['ci_upper']:.4f}])")
    print("="*70)
else:
    print("Test set not found, skipping test evaluation")

# %% [markdown]
# ## 11. Save Final Report

# %%
# Save comparison results
comparison_df.to_csv('results_comparison.csv', index=False)
print("\n✓ All experiments complete!")
print("✓ Results saved to results_comparison.csv")
print("✓ Checkpoints saved in ./checkpoints/")
# Out:
# ✓ All experiments complete!
# ✓ Results saved to results_comparison.csv
# ✓ Checkpoints saved in ./checkpoints/
